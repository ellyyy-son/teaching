# %% [markdown]
# # **Method 1: Web Scraping**

# %% [markdown]
# Install necessary packages

# %%
# %pip install beautifulsoup4 requests openpyxl

# %% [markdown]
# Next, we import the packages into the notebook.
# 1. `pandas`: for managing data through dataframes (https://pandas.pydata.org/docs/)
# 2. `requests`: for connecting to webpages (needs an "agent" to emulate a web browser) (https://requests.readthedocs.io/en/latest/)
# 3. `beautifulsoup`: for processing HTML data collected from webpages (https://www.crummy.com/software/BeautifulSoup/)

# %%
# Import libraries
import numpy as np
import pandas as pd
import requests
from bs4 import BeautifulSoup
import time
import random

# Declare headers for the requests agent
headers = {
  'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36 Edg/127.0.0.0',
  'Accept-Language': 'en-US,en;q=0.9',
  'Accept-Encoding': 'gzip, deflate, br',
  'Connection': 'keep-alive'
}

# %% [markdown]
# Let's try extracting the content of the article from Rappler:
#
# [Sara Duterte face book isang kaibigan](https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/)

# %%
# Define article based on the link
# link = 'https://www.rappler.com/newsbreak/fact-check/sara-duterte-face-book-isang-kaibigan/'
link = 'https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/'

# Request using `request` library
r = requests.get(link, headers=headers)
r
# Out:
# <Response [200]>

# %% [markdown]
# Look at the webpage's content

# %%
# Inspect the content
r.content
# Out:
# b'<!doctype html>\n<html lang="en-US" class="no-js">\n<head>\n\t<meta charset="UTF-8">\n\t<meta name="viewport" content="width=device-width, initial-scale=1">\n\t<script>(function(c){c.add(\'has-js\');c.remove(\'no-js\')})(document.documentElement.classList)</script>\n\t\t<script>\n\t\t(function() {\n\t\t\tconst userAgent = navigator.userAgent;\n\n\t\t\t// Check if user agent contains mobile app identifiers\n\t\t\tif (userAgent.includes("RapplerMobileAndroid") ||\n\t\t\t\tuserAgent.includes("RapplerMobileiOS")) {\n\t\t\t\tdocument.documentElement.classList.add("r6-app");\n\t\t\t\tdocument.body.classList.add("hide-site-header");\n\t\t\t}\n\t\t})();\n\t</script>\n\t\t<meta name=\'robots\' content=\'index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1\' />\n<script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\\/\\/www.rappler.com","id":1},"network":{"url":"https:\\/\\/www.rappler.com","id":1},"post":{"ID":3044525,"slug":"conflict-team-duterte-kaufman-roque-clash","published":"2025-08-01 02:00:00","modified":"2025-08-02 04:05:36","comments":0,"template":"","thumbnail":"https:\\/\\/www.rappler.com\\/tachyon\\/2025\\/08\\/sara-duterte-the-hague-june-3-2025.png","category":["Inside Track","Editors\' Pick","Newsbreak"],"title":"Conflict in Team Duterte: Kaufman and Roque clash","topics":["International Criminal Court","crimes against humanity","Harry Roque","international law","Rodrigo Duterte","Sara Duterte"],"primary_topic":"International Criminal Court","primary_category":"Inside Track","authors":["Lian Buan"],"author_ID":"3706","author_slug":"lian-buan"}} );</script>\n\t\t<!-- Google Tag Manager -->\n\t\t<script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\n\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\n\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\n\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\n\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-WRN3RQG\');</script>\n\t\t<!-- End Google Tag Manager -->\n\t\t\n\t<!-- This site is optimized with the Yoast SEO Premium plugin v23.8 (Yoast SEO v23.8) - https://yoast.com/wordpress/plugins/seo/ -->\n\t<title>Conflict in Team Duterte: Kaufman and Roque clash</title>\n\t<meta name="description" content="&#039;We are too busy working to sustain Harry Roque&#039;s thirst for attention by commenting on his unsolicited and harebrained schemes,&#039; says lead defense counsel Nicholas Kaufman" />\n\t<link rel="canonical" href="https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/" />\n\t<meta property="og:locale" content="en_US" />\n\t<meta property="og:type" content="article" />\n\t<meta property="og:title" content="Conflict in Team Duterte: Kaufman and Roque clash" />\n\t<meta property="og:description" content="&#039;We are too busy working to sustain Harry Roque&#039;s thirst for attention by commenting on his unsolicited and harebrained schemes,&#039; says lead defense counsel Nicholas Kaufman" />\n\t<meta property="og:url" content="https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/" />\n\t<meta property="og:site_name" content="RAPPLER" />\n\t<meta property="article:published_time" content="2025-08-01T02:00:00+00:00" />\n\t<meta property="article:modified_time" content="2025-08-02T04:05:36+00:00" />\n\t<meta property="og:image" content="https://www.rappler.com/uploads/2025/08/sara-duterte-the-hague-june-3-2025-1024x632.png" />\n\t<meta property="og:image:width" content="1024" />\n\t<meta property="og:image:height" content="632" />\n\t<meta property="og:image:type" content="image/png" />\n\t<met ...

# %% [markdown]
# Use `BeautifulSoup` to parse the webpage's HTML source code.

# %%
# Use BeautifulSoup to parse the HTML page
soup = BeautifulSoup(r.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html class="no-js" lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <script>(function(c){c.add('has-js');c.remove('no-js')})(document.documentElement.classList)</script>
# <script>
# 		(function() {
# 			const userAgent = navigator.userAgent;
#
# 			// Check if user agent contains mobile app identifiers
# 			if (userAgent.includes("RapplerMobileAndroid") ||
# 				userAgent.includes("RapplerMobileiOS")) {
# 				document.documentElement.classList.add("r6-app");
# 				document.body.classList.add("hide-site-header");
# 			}
# 		})();
# 	</script>
# <meta content="index, follow, max-image-preview:large, max-snippet:-1, max-video-preview:-1" name="robots">
# <script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\/\/www.rappler.com","id":1},"network":{"url":"https:\/\/www.rappler.com","id":1},"post":{"ID":3044525,"slug":"conflict-team-duterte-kaufman-roque-clash","published":"2025-08-01 02:00:00","modified":"2025-08-02 04:05:36","comments":0,"template":"","thumbnail":"https:\/\/www.rappler.com\/tachyon\/2025\/08\/sara-duterte-the-hague-june-3-2025.png","category":["Inside Track","Editors' Pick","Newsbreak"],"title":"Conflict in Team Duterte: Kaufman and Roque clash","topics":["International Criminal Court","crimes against humanity","Harry Roque","international law","Rodrigo Duterte","Sara Duterte"],"primary_topic":"International Criminal Court","primary_category":"Inside Track","authors":["Lian Buan"],"author_ID":"3706","author_slug":"lian-buan"}} );</script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-WRN3RQG');</script>
# <!-- End Google Tag Manager -->
# <!-- This site is optimized with the Yoast SEO Premium plugin v23.8 (Yoast SEO v23.8) - https://yoast.com/wordpress/plugins/seo/ -->
# <title>Conflict in Team Duterte: Kaufman and Roque clash</title>
# <meta content="'We are too busy working to sustain Harry Roque's thirst for attention by commenting on his unsolicited and harebrained schemes,' says lead defense counsel Nicholas Kaufman" name="description">
# <link href="https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/" rel="canonical"/>
# <meta content="en_US" property="og:locale"/>
# <meta content="article" property="og:type"/>
# <meta content="Conflict in Team Duterte: Kaufman and Roque clash" property="og:title"/>
# <meta content="'We are too busy working to sustain Harry Roque's thirst for attention by commenting on his unsolicited and harebrained schemes,' says lead defense counsel Nicholas Kaufman" property="og:description"/>
# <meta content="https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/" property="og:url"/>
# <meta content="RAPPLER" property="og:site_name"/>
# <meta content="2025-08-01T02:00:00+00:00" property="article:published_time"/>
# <meta content="2025-08-02T04:05:36+00:00" property="article:modified_time"/>
# <meta content="https://www.rappler.com/uploads/2025/08/sara-duterte-the-hague-june-3-2025-1024x632.png" property="og:image"/>
# <meta content="1024" property="og:image:width"/>
# <meta content="632" property="og:image:height"/>
# <meta content="image/png" property="og:image:type"/>
# <meta content="Lian Buan" name="author"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="https://www.rappler.com/tachyon/2025/08/sara-duterte-the-hague-june-3-2025.png" name="twitter:image"/>
# <meta content="@rapplerdotcom" name="twitter:creator"/>
# <meta content="@rapplerdotcom" name="twitter:site"/>
# <script class="yoast-schema-graph" type="application/ld+json">{"@context":"https://schema.org","@graph":[{"@type":"BackgroundNewsArticle","@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#article","isPartOf":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/"},"author":{"@id":"https://www.rappler.com/#/schema/person/d39119ee968a13344ac5c7b02d7a9e2a"},"headline":"Conflict in Team Duterte: Kaufman and Roque clash","datePublished":"2025-08-01T02:00:00+00:00","dateModified":"2025-08-02T04:05:36+00:00","mainEntityOfPage":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/"},"wordCount":566,"commentCount":0,"publisher":{"@id":"https://www.rappler.com/#organization"},"image":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#primaryimage"},"thumbnailUrl":"https://www.rappler.com/tachyon/2025/08/sara-duterte-the-hague-june-3-2025.png","keywords":"International Criminal Court, crimes against humanity, Harry Roque, international law, Rodrigo Duterte, Sara Duterte, Inside Track, Editors' Pick, Newsbreak","articleSection":"International Criminal Court, crimes against humanity, Harry Roque, international law, Rodrigo Duterte, Sara Duterte","inLanguage":"en-US","potentialAction":[{"@type":"CommentAction","name":"Comment","target":["https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#respond"]}],"locationCreated":"Philippines","hasPart":[],"copyrightYear":"2025","copyrightHolder":{"@id":"https://www.rappler.com/#organization"},"video":[{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#video"}]},{"@type":"WebPage","@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/","url":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/","name":"Conflict in Team Duterte: Kaufman and Roque clash","isPartOf":{"@id":"https://www.rappler.com/#website"},"primaryImageOfPage":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#primaryimage"},"image":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#primaryimage"},"thumbnailUrl":"https://www.rappler.com/tachyon/2025/08/sara-duterte-the-hague-june-3-2025.png","datePublished":"2025-08-01T02:00:00+00:00","dateModified":"2025-08-02T04:05:36+00:00","description":"'We are too busy working to sustain Harry Roque's thirst for attention by commenting on his unsolicited and harebrained schemes,' says lead defense counsel Nicholas Kaufman","breadcrumb":{"@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#breadcrumb"},"inLanguage":"en-US","potentialAction":[{"@type":"ReadAction","target":["https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/"]}]},{"@type":"ImageObject","inLanguage":"en-US","@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#primaryimage","url":"https://www.rappler.com/tachyon/2025/08/sara-duterte-the-hague-june-3-2025.png","contentUrl":"https://www.rappler.com/tachyon/2025/08/sara-duterte-the-hague-june-3-2025.png","width":2732,"height":1686,"caption":"SUPPORTERS. Vice President Sara Duterte updates supporters in The Hague after visiting her father at the ICC prison on June 3, 2025."},{"@type":"BreadcrumbList","@id":"https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/#breadcrumb","itemListElement":[{"@type":"ListItem","position":1,"name":"Latest News","item":"https://www.rappler.com/latest/"},{"@type":"ListItem","position":2,"name":"Conflict in Team Duterte: Kaufman and Roque clash"}]},{"@type":"WebSite","@id":"https://www.rappler.com/#website","url":"https://www.rappler.com/","name":"RAPPLER","descriptio ...
# <meta content="https://www.youtube.com/embed/7jxoxX8cloA" property="og:video"/>
# <meta content="text/html" property="og:video:type"/>
# <meta content="676" property="og:video:duration"/>
# <meta content="480" property="og:video:width"/>
# <meta content="270" property="og:video:height"/>
# <meta content="false" property="ya:ovs:adult"/>
# <meta content="2025-08-01T02:00:00+00:00" property="ya:ovs:upload_date"/>
# <meta content="true" property="ya:ovs:allow_embed"/>
# <!-- / Yoast SEO Premium plugin. -->
# <link href="https://www.rappler.com/feed/" rel="alternate" title="RAPPLER » Feed" type="application/rss+xml"/>
# <link href="https://www.rappler.com/comments/feed/" rel="alternate" title="RAPPLER » Comments Feed" type="application/rss+xml"/>
# <link href="https://www.rappler.com/newsbreak/inside-track/conflict-team-duterte-kaufman-roque-clash/feed/" rel="alternate" title="RAPPLER » Conflict in Team Duterte: Kaufman and Roque clash Comments Feed" type="application/rss+xml"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/1cdec6e278f2e85e40f08af1112576f3.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/6bbaad76a4547e68e0111da3ce1c929f.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/8a64d0d4cd2b8d0ee70b9f60ecfbe8f8.woff2" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="https://www.rappler.com/content/themes/rappler/build/f55a0177f65edc649d6e45ba6a5a173f.woff2" rel="preload" type="font/woff2"/>
# <link as="style" href="https://www.rappler.com/wp-includes/css/dist/block-library/style.min.css?ver=6.6.2" rel="preload"/>
# <link as="style" href="https://www.rappler.com/content/themes/rappler/build/rappler-theme-style.2d8f990814988b525d2e.css" rel="preload"/>
# <link as="style" href="https://www.rappler.com/content/mu-plugins/rappler-blocks/build/rappler-blocks-frontend.d2edfed216c0e3671c75.css" rel="preload"/>
# <link href="https://cdn.datatables.net/v/dt/dt-2.1.7/fc-5.0.1/r-3.0.3/sc-2.4.3/datatables.min.css?ver=6.6.2" id="datatables-css-css" media="all" rel="stylesheet"/>
# <link href="https://www.rappler.com/wp-includes/css/dist/block-library/style.min.css?ver=6.6.2" id="wp-block-library-css" media="all" rel="stylesheet"/>
# <style id="classic-theme-styles-inline-css">
# /*! This file is auto-generated */
# .wp-block-button__link{color:#fff;background-color:#32373c;border-radius:9999px;box-shadow:none;text-decoration:none;padding:calc(.667em + 2px) calc(1.333em + 2px);font-size:1.125em}.wp-block-file__button{background:#32373c;color:#fff;text-decoration:none}
# </style>
# <style id="global-styles-inline-css">
# :root{--wp--preset--aspect-ratio--square: 1;--wp--preset--aspect-ratio--4-3: 4/3;--wp--preset--aspect-ratio--3-4: 3/4;--wp--preset--aspect-ratio--3-2: 3/2;--wp--preset--aspect-ratio--2-3: 2/3;--wp--preset--aspect-ratio--16-9: 16/9;--wp--preset--aspect-ratio--9-16: 9/16;--wp--preset--color--black: #000000;--wp--preset--color--cyan-bluish-gray: #abb8c3;--wp--preset--color--white: #ffffff;--wp--preset--color--pale-pink: #f78da7;--wp--preset--color--vivid-red: #cf2e2e;--wp--preset--color--luminous-vivid-orange: #ff6900;--wp--preset--color--luminous-vivid-amber: #fcb900;--wp--preset--color--light-green-cyan: #7bdcb5;--wp--preset--color--vivid-green-cyan: #00d084;--wp--preset--color--pale-cyan-blue: #8ed1fc;--wp--preset--color--vivid-cyan-blue: #0693e3;--wp--preset--color--vivid-purple: #9b51e0;--wp--preset--color--navy: #172038;--wp--preset--color--orange-courage: #f04f3c;--wp--preset--color--ghost-white: #f5f6ff;--wp--preset--color--mint: #c7e4da;--wp--preset--color--vanilla: #fff;--wp--preset--color--move: #50558b;--wp--preset--gradient--vivid-cyan-blue-to-vivid-purple: linear-gradient(135deg,rgba(6,147,227,1) 0%,rgb(155,81,224) 100%);--wp--preset--gradient--light-green-cyan-to-vivid-green-cyan: linear-gradient(135deg,rgb(122,220,180) 0%,rgb(0,208,130) 100%);--wp--preset--gradient--luminous-vivid-amber-to-luminous-vivid-orange: linear-gradient(135deg,rgba(252,185,0,1) 0%,rgba(255,105,0,1) 100%);--wp--preset--gradient--luminous-vivid-orange-to-vivid-red: linear-gradient(135deg,rgba(255,105,0,1) 0%,rgb(207,46,46) 100%);--wp--preset--gradient--very-light-gray-to-cyan-bluish-gray: linear-gradient(135deg,rgb(238,238,238) 0%,rgb(169,184,195) 100%);--wp--preset--gradient--cool-to-warm-spectrum: linear-gradient(135deg,rgb(74,234,220) 0%,rgb(151,120,209) 20%,rgb(207,42,186) 40%,rgb(238,44,130) 60%,rgb(251,105,98) 80%,rgb(254,248,76) 100%);--wp--preset--gradient--blush-light-purple: linear-gradient(135deg,rgb(255,206,236) 0%,rgb(152,150,240) 100%);--wp--preset--gradient--blush-bordeaux: linear-gradient(135deg,rgb(254,205,165) 0%,rgb(254,45,45) 50%,rgb(107,0,62) 100%);--wp--preset--gradient--luminous-dusk: linear-gradient(135deg,rgb(255,203,112) 0%,rgb(199,81,192) 50%,rgb(65,88,208) 100%);--wp--preset--gradient--pale-ocean: linear-gradient(135deg,rgb(255,245,203) 0%,rgb(182,227,212) 50%,rgb(51,167,181) 100%);--wp--preset--gradient--electric-grass: linear-gradient(135deg,rgb(202,248,128) 0%,rgb(113,206,126) 100%);--wp--preset--gradient--midnight: linear-gradient(135deg,rgb(2,3,129) 0%,rgb(40,116,252) 100%);--wp--preset--font-size--small: 13px;--wp--preset--font-size--medium: 20px;--wp--preset--font-size--large: 36px;--wp--preset--font-size--x-large: 42px;--wp--preset--spacing--20: 0.44rem;--wp--preset--spacing--30: 0.67rem;--wp--preset--spacing--40: 1rem;--wp--preset--spacing--50: 1.5rem;--wp--preset--spacing--60: 2.25rem;--wp--preset--spacing--70: 3.38rem;--wp--preset--spacing--80: 5.06rem;--wp--preset--shadow--natural: 6px 6px 9px rgba(0, 0, 0, 0.2);--wp--preset--shadow--deep: 12px 12px 50px rgba(0, 0, 0, 0.4);--wp--preset--shadow--sharp: 6px 6px 0px rgba(0, 0, 0, 0.2);--wp--preset--shadow--outlined: 6px 6px 0px -3px rgba(255, 255, 255, 1), 6px 6px rgba(0, 0, 0, 1);--wp--preset--shadow--crisp: 6px 6px 0px rgba(0, 0, 0, 1);}:where(.is-layout-flex){gap: 0.5em;}:where(.is-layout-grid){gap: 0.5em;}body .is-layout-flex{display: flex;}.is-layout-flex{flex-wrap: wrap;align-items: center;}.is-layout-flex > :is(*, div){margin: 0;}body .is-layout-grid{display: grid;}.is-layout-grid > :is(*, div){margin: 0;}:where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}:where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}.has-black-color{color: var(--wp--preset--color--black) !important;}.has-cyan-bluish-gray-color{color: var(--wp--preset--color--cyan-bluish-gray) !important;}.has-white-color{color: var(--wp--preset--color--white) !important;}.ha ...
# :where(.wp-block-post-template.is-layout-flex){gap: 1.25em;}:where(.wp-block-post-template.is-layout-grid){gap: 1.25em;}
# :where(.wp-block-columns.is-layout-flex){gap: 2em;}:where(.wp-block-columns.is-layout-grid){gap: 2em;}
# :root :where(.wp-block-pullquote){font-size: 1.5em;line-height: 1.6;}
# </style>
# <style id="rappler-theme-style-load-inline-css">
# /*! normalize.css v8.0.1 | MIT License | github.com/necolas/normalize.css */html{line-height:1.15;-webkit-text-size-adjust:100%}body{margin:0}main{display:block}h1{font-size:2em;margin:.67em 0}hr{box-sizing:content-box;height:0;overflow:visible}pre{font-family:monospace,monospace;font-size:1em}a{background-color:transparent}abbr[title]{border-bottom:none;text-decoration:underline;-webkit-text-decoration:underline dotted;text-decoration:underline dotted}b,strong{font-weight:bolder}code,kbd,samp{font-family:monospace,monospace;font-size:1em}small{font-size:80%}sub,sup{font-size:75%;line-height:0;position:relative;vertical-align:baseline}sub{bottom:-.25em}sup{top:-.5em}img{border-style:none}button,input,optgroup,select,textarea{font-family:inherit;font-size:100%;line-height:1.15;margin:0}button,input{overflow:visible}button,select{text-transform:none}[type=button],[type=reset],[type=submit],button{-webkit-appearance:button}[type=button]::-moz-focus-inner,[type=reset]::-moz-focus-inner,[type=submit]::-moz-focus-inner,button::-moz-focus-inner{border-style:none;padding:0}[type=button]:-moz-focusring,[type=reset]:-moz-focusring,[type=submit]:-moz-focusring,button:-moz-focusring{outline:1px dotted ButtonText}fieldset{padding:.35em .75em .625em}legend{box-sizing:border-box;color:inherit;display:table;max-width:100%;padding:0;white-space:normal}progress{vertical-align:baseline}textarea{overflow:auto}[type=checkbox],[type=radio]{box-sizing:border-box;padding:0}[type=number]::-webkit-inner-spin-button,[type=number]::-webkit-outer-spin-button{height:auto}[type=search]{-webkit-appearance:textfield;outline-offset:-2px}[type=search]::-webkit-search-decoration{-webkit-appearance:none}::-webkit-file-upload-button{-webkit-appearance:button;font:inherit}details{display:block}summary{display:list-item}[hidden],template{display:none}:root{--white:#fff;--black:#000;--navy:#172038;--navy-dark:#121a2d;--navy-light:#454d60;--orange-courage:#ff5f1b;--orange-courage-light:#ff8c5a;--ghost-white:#f5f6ff;--ash:#ebedff;--blueblack:#18213a;--hustle:#1e1558;--midblue:#575d75;--midnight:#101626;--midnight-light:#404551;--midnight-lighter:#70737d;--mint:#c7e4da;--move:#50558b;--move-dark:#404464;--move-light:#7377a2;--system-gray:#6c6f8b;--system-gray-dark:#56596f;--system-gray-darker:#414353;--vanilla:#fff;--vanilla-dark:#eeeef3;--vanilla-darker:#cbccdc;--wave:#261c6c;--nerve:#6c6f8b;--afraid:#f9e950;--afraid-dark:#496667;--afraid-light:#6b8788;--amused:#79cbf9;--amused-dark:#2de133;--amused-light:#71ff75;--angry:#f8505e;--angry-dark:#df1f1f;--angry-light:#ff4949;--annoyed:#935bb8;--annoyed-dark:#8142ab;--annoyed-light:#af6eda;--dont-care:#bab9b9;--dont-care-dark:#b0b0b0;--dont-care-light:#cccbcb;--happy:#fecc32;--happy-dark:#f0ba12;--happy-light:#ffd862;--inspired:#ff6f31;--inspired-dark:#ff5f1b;--inspired-light:#ff8551;--sad:#669cd0;--sad-dark:#528fca;--sad-light:#6da8df;--nerve-angry:#fa2c2c;--events-black:#151515;--events-bluepurple:#50558b;--events-error:#fabebe;--events-gold:#e4b130;--events-maroon:#510d69;--events-lightgrey:#caccd8;--default-background-color:var(--ghost-white);--default-background-color-alt:var(--navy);--default-text-color:var(--navy);--default-text-color-alt:var(--white);--default-border-color:var(--navy);--default-border-color-alt:var(--white);--default-cta-color:var(--navy);--heading-one-color:var(--navy);--heading-two-color:var(--navy);--heading-three-color:var(--navy);--heading-four-color:var(--navy);--heading-five-color:var(--navy);--heading-six-color:var(--navy)}.has-navy-background-color{background-color:#172038;background-color:var(--navy)}.has-navy-color{color:#172038;color:var(--navy)}.has-orange-courage-background-color{background-color:#ff5f1b;background-color:var(--orange-courage)}.has-orange-courage-color{color:#ff5f1b;color:var(--orange-courage)}.has-ghost-white-background-color{background-color:#f5f6ff;background-color:var(--ghost-white)}.has-ghost-white-color{color:#f5f6ff;color:var(--ghost-white)}.has-midnight-backgrou ...
# </style>
# <link href="https://www.rappler.com/content/themes/rappler/build/rappler-theme-style.2d8f990814988b525d2e.css?ver=2d8f990814988b525d2e" id="rappler-theme-style-css" integrity="sha384-FnX2U5NeZHWDfvx87CTYEzwyw2aMDN5Tcc3X/9j8IaqD/JzHVPFKGbwAiY0Vrt54" media="all" rel="stylesheet"/>
# <link href="https://www.rappler.com/content/mu-plugins/rappler-blocks/build/rappler-blocks-frontend.d2edfed216c0e3671c75.css?ver=d2edfed216c0e3671c75" id="rappler-blocks-frontend-css" integrity="sha384-CrIrt2L9ln9OP+yKI3z0cCdz9X/YdkZskl1koc+qIa/PWz2Uo71DqObk0EP4azuO" media="all" rel="stylesheet"/>
# <script id="lazy-load-scripts-footer-before">rapplerCxense = {"load_inline_from_composer":"yes","widget_inline_article_id":"2babd9be39f41eff3abcbdc513a4d3d4bbca8a33","element_inline_article_id":"cx_inline","widget_after_article_id":"8ae670c83901191ea83ddc6768902cc0fe07315f","element_after_article_id":"cx_after-article","use_soft_section_after_article":false,"soft_section_widget_id":"1aca31944a2782773a98fa3c056877dad633f8aa","widget_related_topics_id":"a0da9e337862e0626476a632f993ba817f7b06fb","element_related_topics_id":"cx_related-topics-widget"};window.tp = window.tp || [];rapplerPianoId = {"elements":{".masthead":"masthead--logged-in",".burger-nav":"burger-nav--logged-in"},"logout_button":"","piano_id_form":"piano-id-form-overlay","rappler_plus_offer_id":"OFIZWP6GZ6I9","rappler_plus_template_id":"OTOVFQ3UAN4R","subscriber_rid":"R2Q6QPY"};var rapplerSpeechify = {"content_selector":"article.single-article.post","element_id":"rappler-speechify","ignored_el_classes":["rappler-speechify","author-block","comments","dailymotion-container","piano-article__plea","piano-article__prearticle","post-single__category","post-single__ai-summary-section-container","post-single__image","post-single__moodmeter","post-single__end-article-moodmeter","post-single__related-topics-widget","post-single__share","post-single__taboola","rappler-ad-container","recommended-articles","related-article","related-topics","video-embed-container"],"primary_color":"#f04f3c"};</script><script async="" id="cxense-script-js" src="https://cdn.cxense.com/cx.cce.js?ver=6.6.2"></script>
# <script id="jquery-core-js" src="https://www.rappler.com/wp-includes/js/jquery/jquery.min.js?ver=3.7.1"></script>
# <script id="jquery-migrate-js" src="https://www.rappler.com/wp-includes/js/jquery/jquery-migrate.min.js?ver=3.4.1"></script>
# <script async="" id="rappler-gpt-js" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script id="rappler-gpt-js-after">
# window.rapplerAds = {"availableSlots":{"top-billboard":{"path":"R6_Desktop\/Article\/R6_Top_Billboard","sizes":[[970,90],[728,90]],"device":"desktop","collapseEmptyDiv":false},"middle-1":{"path":"R6_Desktop\/Article\/R6_Middle_1","mobile":"R6_Mobile\/Article\/R6_Middle_1","sizes":[[300,250],[336,280]],"device":"desktop","collapseEmptyDiv":false},"middle-2":{"path":"R6_Desktop\/Article\/R6_Middle_2","sizes":[[300,250],[336,280]],"device":"desktop","collapseEmptyDiv":false},"middle-3":{"path":"R6_Desktop\/Article\/R6_Middle_3","sizes":[[300,250],[336,280]],"device":"desktop","collapseEmptyDiv":false},"sticky-leaderboard":{"path":"R6_Desktop\/Article\/R6_Sticky_Leaderboard","sizes":[[970,90],[728,90]],"device":"desktop"},"bottom-leaderboard":{"path":"R6_Desktop\/Article\/R6_Bottom_Leaderboard","sizes":[[728,90]],"device":"desktop","collapseEmptyDiv":false},"oop":{"path":"R6_Desktop\/Article\/OOP","sizes":[[1,1]],"device":"desktop","isOop":true},"mobile-top-billboard":{"path":"R6_Mobile\/Article\/R6_Top_Billboard","sizes":[[320,100],[300,100],[320,50],[300,50]],"device":"mobile","collapseEmptyDiv":false,"minHeight":70},"mobile-middle-1":{"path":"R6_Mobile\/Article\/R6_Middle_1","sizes":[[300,250],[336,280]],"device":"mobile","collapseEmptyDiv":false},"mobile-middle-2":{"path":"R6_Mobile\/Article\/R6_Middle_2","sizes":[[300,250],[336,280]],"device":"mobile"},"mobile-middle-3":{"path":"R6_Mobile\/Article\/R6_Middle_3","sizes":[[300,250],[336,280]],"device":"mobile"},"mobile-sticky-leaderboard":{"path":"R6_Mobile\/Topic\/R6_Sticky_Leaderboard","sizes":[[320,50]],"device":"mobile"},"mobile-bottom-leaderboard":{"path":"R6_Mobile\/Article\/R6_Bottom_Leaderboard","sizes":[[320,50]],"device":"mobile","collapseEmptyDiv":false},"mobile-oop":{"path":"R6_Mobile\/Article\/R6_OOP","sizes":[[1,1]],"device":"mobile","isOop":true}},"targeting":{"page_type":"Article","articleID":["3044525"],"Topic":["crimes-against-humanity","harry-roque","international-criminal-court","international-law","rodrigo-duterte","sara-duterte"],"Section":["editors-pick"],"Subsection":["inside-track"]},"adpushupEnabled":true,"networkCode":"15125093","persistedQueryId":"82ef547962d8ecd598da83a1543cb91a6670175e","definedSlots":[],"queue":[],"breakpoints":{"desktop":[1024,100],"tablet":[768,100]},"initialized":false,"ads_free_mode":true,"disabled":false};
# 	window.rapplerAds.displayAd = function ( id, divId ) {
# 		window.cX = window.cX || {};
# 		window.cX.callQueue = window.cX.callQueue || [];
# 		window.googletag = window.googletag || { cmd: [] };
# 		window.rapplerAds = window.rapplerAds || {};
# 		/**
# 		 * Callback to display Ads.
# 		 */
# 		function callback() {
# 			window.cX.callQueue.push( [
# 				'invoke',
# 				function () {
# 					const currSlot = window.rapplerAds.availableSlots[id];
# 					// define slot if ad is dynamic
# 					if ( currSlot.insertedDynamically ) {
# 						window.googletag.cmd.push( () => {
# 							window.rapplerAds.defineAdSlot( id, true );
# 						} );
# 					}
#
# 					// define slot if ad is reusable
# 					if ( currSlot.isReusable && divId ) {
# 						window.googletag.cmd.push( () => {
# 							window.rapplerAds.defineAdSlot( id, false, divId );
# 						} );
# 					}
#
# 					window.googletag.cmd.push( () => {
# 						if (!divId) divId = 'gpt-' + id;
#
# 						if ( divId === 'gpt-sticky-leaderboard' || divId === 'gpt-top-billboard' || divId === 'gpt-mobile-top-billboard' ) {
# 							window.googletag.display(divId);
# 						}
# 						//window.googletag.display(divId);
# 					} );
# 				},
# 			] );
# 		}
#
# 		if ( window.rapplerAds.initialized ) {
# 			callback();
# 		} else {
# 			window.rapplerAds.queue.push( callback );
# 		}
# 	};
# 	// Lazy load other ad slots
# 	(function(){
# 		// IDs to display in the next batch
# 		const pending = new Set ();
# 		let  batchTimer = null;
# 		const slots = {};
#
# 		function flushBatch() {
# 			if (!pending.size) return;
# 			// Log all newly visible slots
# 			//console.log('Displaying lazy ad slots: ', pending);
# 			window.googletag.cmd.push( () => {
# 			// Display all newly visible slots in one go -> one SRA request for this batch
# 			pending.forEach(function(id) {
# 				window.googletag.display(id);
# 				console.log('Displaying lazy ad slots: ', id);
# 			});
# 			pending.clear();
# 			});
# 			batchTimer = null;
# 		}
#
# 		// Observe only the lazy ones
# 		const io = new IntersectionObserver((entries) => {
# 			entries.forEach(entry => {
# 			if (entry.isIntersecting) {
# 				const id = entry.target.id;
# 				// Guard: only queue if not displayed yet
# 				// if (slots[id] && !entry.target.dataset.displayed) {
# 				if (!entry.target.dataset.displayed) {
# 					entry.target.dataset.displayed = "1";
# 					pending.add(id);
# 					// micro-batching window to group near-simultaneous reveals
# 					if (!batchTimer) batchTimer = setTimeout(flushBatch, 0);
# 				}
# 				io.unobserve(entry.target);
# 			}
# 			});
# 		}, { rootMargin: '0px 0px 0px 0px', threshold: 0.5 });
#
# 		window.addEventListener('DOMContentLoaded', function() {
# 			document.querySelectorAll('.rappler-ad').forEach(el => io.observe(el));
# 		});
# 	})();
# </script>
# <script async="" id="rappler-gpt-init-js" src="https://www.rappler.com/content/mu-plugins/rappler-ads/assets/build/rappler-gpt-init.74d91704473ba3d199d0.js?ver=74d91704473ba3d199d0"></script>
# <meta content="Conflict in Team Duterte: Kaufman and Roque clash" name="cXenseParse:title"/><meta content="post" name="cXenseParse:pageclass"/><meta content="post" name="section"/><meta content="post" name="cXenseParse:rap-articletype"/><meta content="2025-08-01T10:00:00Z" name="cXenseParse:publishtime"/><meta content="2025-08-01T10:00:00Z" name="cXenseParse:recs:publishtime"/><meta content="3044525" name="cXenseParse:articleid"/><meta content="Lian Buan" name="cXenseParse:author"/><meta content="crimes against humanity, Harry Roque, International Criminal Court, international law, Rodrigo Duterte, Sara Duterte" data-separator="," name="cXenseParse:keywords"/><meta content="crimes against humanity, Harry Roque, International Criminal Court, international law, Rodrigo Duterte, Sara Duterte" data-separator="," name="cXenseParse:rap-keywords"/><meta content="crimes against humanity, Harry Roque, International Criminal Court, international law, Rodrigo Duterte, Sara Duterte" data-separator="," name="cXenseParse:rap-topics"/><meta content="RAPPLER" name="cXenseParse:sitename"/><meta content="true" name="cXenseParse:mainsite"/><meta content="International Criminal Court" name="cXenseParse:primarytopic"/><meta content="International Criminal Court" name="cXenseParse:rap-primaryTopic"/><meta content="https://www.rappler.com/topic/international-criminal-court/" name="cXenseParse:rap-primaryTopicUrl"/><meta content="Inside Track" name="cXenseParse:primarysection"/><meta content="Inside Track" name="cXenseParse:rap-primarySection"/><meta content="https://www.rappler.com/newsbreak/inside-track/" name="cXenseParse:rap-primarySectionUrl"/><meta content="true" name="cXenseParse:rap-editorsPick"/>
# <meta content="crimes against humanity" property="article:tag"/>
# <meta content="Harry Roque" property="article:tag"/>
# <meta content="International Criminal Court" property="article:tag"/>
# <meta content="international law" property="article:tag"/>
# <meta content="Rodrigo Duterte" property="article:tag"/>
# <meta content="Sara Duterte" property="article:tag"/>
# <link href="https://www.rappler.com/wp-json/" rel="https://api.w.org/"/><link href="https://www.rappler.com/wp-json/wp/v2/posts/3044525" rel="alternate" title="JSON" type="application/json"/><link href="https://www.rappler.com/xmlrpc.php?rsd" rel="EditURI" title="RSD" type="application/rsd+xml"/>
# <meta content="Altis (WordPress 6.6.2)" name="generator"/>
# <link href="https://www.rappler.com/?p=3044525" rel="shortlink"/>
# <link href="https://www.rappler.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.rappler.com%2Fnewsbreak%2Finside-track%2Fconflict-team-duterte-kaufman-roque-clash%2F" rel="alternate" title="oEmbed (JSON)" type="application/json+oembed"/>
# <link href="https://www.rappler.com/wp-json/oembed/1.0/embed?url=https%3A%2F%2Fwww.rappler.com%2Fnewsbreak%2Finside-track%2Fconflict-team-duterte-kaufman-roque-clash%2F&amp;format=xml" rel="alternate" title="oEmbed (XML)" type="text/xml+oembed"/>
# <!-- Stream WordPress user activity plugin v3.10.1 -->
# <script type="text/javascript">
# 		"use strict";!function(){for(var t,e;!(t=window.document.getElementsByTagName("head")[0]);)window.document.getElementsByTagName("html")[0].appendChild(window.document.createElement("head"));"function"!=typeof window.document.querySelectorAll&&((e=window.document.createElement("script")).type="text/javascript",e.charset="utf-8",e.setAttribute("crossorigin","anonymous"),e.async=!0,e.src=(window.document.location.protocol||"http:")+"//api.deep.bi/v3/sizzle.js",t.appendChild(e)),(e=window.document.createElement("script")).type="text/javascript",e.charset="utf-8",e.setAttribute("crossorigin","anonymous"),e.async=!0,e.src=(window.document.location.protocol||"http:")+"//api.deep.bi/v3/init.js",t.appendChild(e)}();
# 	</script>
# <script type="text/javascript">
# 		r(function () {
# 			window.deep = window.deepTracker.track("TR8x0HLI2e7B", "soI2uyBN7c7KXjgBwLE2s2oY");
# 			window.deep.options.media = true;
# 			window.deep.options.dntignore = true;
#
# 			window.deep.options.dataCollector = true;
# 			window.deep.options.globalVariablesDataCollector = true;
# 			window.deep.options.scrolldepth = true;
# 			window.deep();
# 		});
# 		function r(f) {
# 			if (!window.deepTracker || !window.deepTracker.isInitialized()) {
# 				setTimeout('r(' + f + ')', 9);
# 			} else {
# 				f();
# 			}
# 		}
# 	</script>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png?fit=32%2C32" rel="icon" sizes="32x32"/>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" rel="icon" sizes="192x192"/>
# <link href="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" rel="apple-touch-icon"/>
# <meta content="https://www.rappler.com/tachyon/2022/11/cropped-Piano-Small.png" name="msapplication-TileImage"/>
# </meta></meta></head>
# <body class="post-template-default single single-post postid-3044525 single-format-standard wp-custom-logo wp-embed-responsive">
# <script>window.dataLayer = window.dataLayer || []; window.dataLayer.push( {"type":"post","subtype":"post","context":{"is_front_page":false,"is_singular":true,"is_archive":false,"is_home":false,"is_search":false,"is_404":false,"is_post_type_archive":false,"is_tax":false,"is_article":true},"user":{"role":[]},"blog":{"url":"https:\/\/www.rappler.com","id":1},"network":{"url":"https:\/\/www.rappler.com","id":1},"post":{"ID":3044525,"slug":"conflict-team-duterte-kaufman-roque-clash","published":"2025-08-01 02:00:00","modified":"2025-08-02 04:05:36","comments":0,"template":"","thumbnail":"https:\/\/www.rappler.com\/tachyon\/2025\/08\/sara-duterte-the-hague-june-3-2025.png","category":["Inside Track","Editors' Pick","Newsbreak"],"title":"Conflict in Team Duterte: Kaufman and Roque clash","topics":["International Criminal Court","crimes against humanity","Harry Roque","international law","Rodrigo Duterte","Sara Duterte"],"primary_topic":"International Criminal Court","primary_category":"Inside Track","authors":["Lian Buan"],"author_ID":"3706","author_slug":"lian-buan"}} );</script>
# <!-- Google Tag Manager -->
# <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 		new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 		j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 		'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 		})(window,document,'script','dataLayer','GTM-WRN3RQG');</script>
# <!-- End Google Tag Manager -->
# <header class="site-header">
# <div class="masthead masthead-upper">
# <div class="masthead__nav">
# <button aria-expanded="false" class="masthead__nav--burger-button" id="burger-nav__toggle">
# <span class="masthead__nav--burger">
# <span class="masthead__nav--burger-icon"></span>
# <span class="masthead__nav--burger-icon"></span>
# </span>
# <span class="screen-reader-text">Open navigation</span>
# </button>
# <a class="masthead__breadcrumbs--taxonomy-label" href="https://www.rappler.com/newsbreak/inside-track/">Inside Track</a><div aria-hidden="true" aria-labelledby="burger-nav__toggle" class="burger-nav-overlay burger-nav-overlay--no-transition" id="burger-nav-overlay">
# <nav class="burger-nav" id="burger-navigation">
# <div class="burger-nav__top-bar" id="burger-nav__top-bar">
# <div class="burger-nav__top-bar-left">
# <div class="burger-nav__logo" id="burger-nav__logo">
# <a class="logo" href="#">
# <span class="screen-reader-text">
# 							RAPPLER						</span>
# <svg fill="none" height="41" viewbox="0 0 48 41" width="48" xmlns="http://www.w3.org/2000/svg"><path clip-rule="evenodd" d="M20.6008 39.6121C14.7202 38.2578 10.3871 34.9926 7.3622 30.7105C5.63816 28.2705 4.28467 25.3317 3.74304 21.6822C3.16392 17.7819 3.86575 13.8049 5.0131 10.8168C3.4027 13.8755 2.33273 17.2387 2.63196 21.4923C2.77039 23.4683 3.23042 25.2592 3.77508 26.8772C4.32336 28.5067 4.97985 29.9786 5.83885 31.3755C8.91638 36.3774 14.2481 39.4995 21.776 39.9915C22.2977 40.0256 22.9741 40.1383 23.3634 40.0548C23.3326 40.0621 22.8556 39.986 22.6332 39.9604C21.9005 39.8758 21.2223 39.7546 20.6008 39.6121ZM6.69544 27.2572C8.66793 31.5886 12.3705 34.5286 16.5053 36.4754C14.3871 28.5993 12.2672 20.7262 10.1556 12.844C9.16484 12.5547 8.2605 12.1796 7.26669 11.8934C6.02685 13.7026 5.19929 16.4282 5.1074 19.3378C5.01552 22.2747 5.70707 25.0881 6.69544 27.2572ZM25.1086 21.175C26.5141 20.4984 28.1565 19.2373 28.1565 17.2473C28.1565 16.0355 27.5726 14.8511 26.95 14.1429C26.2578 13.3555 25.1316 12.8434 23.7751 12.9073C21.4139 13.0187 19.3943 14.0095 17.235 14.4595C18.0353 17.1456 18.7819 19.8858 19.5526 22.6005C20.5168 22.4
# </svg>
# <span class="screen-reader-text">Share article</span>
# </button>
# <div class="social-share__more-actions">
# <div class="social-share__more-actions__triangle"></div>
# <div class="social-share__more-actions__label">
# <div class="social-share__more-actions__buttons">
# <a class="social-icon social-icon--facebook" href="https://facebook.com/sharer/sharer.php?u=https%3A%2F%2Frappler.com&amp;utm_source=fb_share&amp;utm_medium=social" rel="noopener noreferrer" target="_blank">
# <svg fill="none" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M24 2.21484C24 1.39453 23.3203 0.714844 22.5 0.714844H1.5C0.679688 0.714844 0 1.39453 0 2.21484V23.2148C0 24.0352 0.679688 24.7148 1.5 24.7148H12.832V15.3867H9.83203V11.9297H12.832V8.94141C12.832 6.21094 14.4961 4.38281 17.7891 4.38281C19.2422 4.38281 20.25 4.54688 20.25 4.54688V7.66406H18C17.0039 7.66406 16.5 8.22656 16.5 9.21094V11.9297H20.0039L19.5 15.3867H16.5V24.7148H22.5C23.3203 24.7148 24 24.0352 24 23.2148V2.21484Z" fill="currentColor"></path>
# </svg>
# <span class="social-icon--label">Facebook</span>
# </a>
# <a class="social-icon social-icon--twitter" href="https://twitter.com/intent/tweet?url=https%3A%2F%2Frappler.com&amp;text=title&amp;via=rapplerdotcom&amp;utm_source=tw_share&amp;utm_medium=social" rel="noopener noreferrer" target="_blank">
# <svg fill="none" height="24" viewbox="0 0 24 24" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M18.244 2.25h3.308l-7.227 8.26 8.502 11.24H16.17l-5.214-6.817L4.99 21.75H1.68l7.73-8.835L1.254 2.25H8.08l4.713 6.231zm-1.161 17.52h1.833L7.084 4.126H5.117z" fill="currentColor"></path>
# </svg>
# <span class="social-icon--label">X (Twitter)</span>
# </a>
# <hr/>
# <a class="social-icon social-icon--copy" data-permalink="https://rappler.com" href="https://rappler.com" rel="noopener noreferrer" type="button">
# <svg fill="none" height="25" viewbox="0 0 24 25" width="24" xmlns="http://www.w3.org/2000/svg">
# <path d="M22.0764 11.8204C24.6412 9.26724 24.6412 5.15647 22.0764 2.63847C19.5584 0.0736336 15.4476 0.0736336 12.8945 2.63847L9.17018 6.35105C6.65219 8.88076 6.65219 12.9915 9.17018 15.5447C9.75576 16.1302 10.7044 16.1302 11.2783 15.5447C11.899 14.9591 11.899 14.0104 11.2783 13.4366C9.91973 12.0429 9.91973 9.85282 11.2783 8.45914L15.026 4.74656C16.3962 3.38802 18.6097 3.38802 19.9683 4.74656C21.3268 6.10511 21.3268 8.3186 19.9683 9.68886L18.1998 11.4924C18.6449 12.687 18.8088 13.9285 18.6917 15.205L22.0764 11.8204ZM14.8386 19.0699C17.3566 16.5401 17.3566 12.4294 14.8386 9.87624C14.253 9.29066 13.281 9.29066 12.6954 9.87624C12.1098 10.4618 12.1098 11.4339 12.6954 12.0195C14.0891 13.378 14.0891 15.6032 12.6954 16.9618L8.9828 20.6743C7.61254 22.0329 5.39905 22.0329 4.0405 20.6743C2.68196 19.3158 2.68196 17.1023 4.0405 15.732L5.80895 13.9636C5.36391 12.769 5.19995 11.4924 5.31707 10.2159L1.89728 13.624C-0.632427 16.1537 -0.632427 20.2644 1.89728 22.8176C4.45041 25.3473 8.56118 25.3473 11.0909 22.8176L14.8386 19.0699Z" fill="currentColor"></path>
# </svg>
# <span class="social-icon--label">Copy Link</span>
# </a>
# <div class="social-share__actions-tooltip">
# <span class="tooltip-dark">
# 						Copied					</span>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="video-modal__link-container">
# <a class="video-modal__post-redirect">
# <div>READ</div>
# <svg fill="none" height="13" viewbox="0 0 8 13" width="8" xmlns="http://www.w3.org/2000/svg">
# <path d="M1.99984 0.5L0.589844 1.91L5.16984 6.5L0.589844 11.09L1.99984 12.5L7.99984 6.5L1.99984 0.5Z" fill="white"></path>
# </svg>
# </a>
# </div>
# </div>
# </div>
# </template>
# <div class="rappler-ad-container sticky-leaderboard">
# <div class="rappler-ad rappler-ad--sticky-leaderboard rappler-ad--desktop" id="gpt-sticky-leaderboard" style="min-width: 970px; min-height: 105px;">
# <div class="rappler-ad-placeholder" style="width: 728px; height: 90px;">
# </div>
# </div>
# <script>
# 									window.rapplerAds.displayAd( "sticky-leaderboard" );
# 							</script>
# </div>
# <div class="rappler-ad-container sticky-leaderboard">
# <div class="rappler-ad rappler-ad--mobile-sticky-leaderboard rappler-ad--mobile" id="gpt-mobile-sticky-leaderboard" style="min-width: 360px; min-height: 65px;">
# <div class="rappler-ad-placeholder" style="width: 320px; height: 50px;">
# </div>
# </div>
# <script>
# 									window.rapplerAds.displayAd( "mobile-sticky-leaderboard" );
# 							</script>
# </div>
# <script>
# 		(function() {
# 			document.querySelectorAll( '.sticky-leaderboard' ).forEach( function( stickyEl ) {
# 				// Create close button and append to container.
# 				var closeBtnEl = document.createElement( 'button' );
# 				closeBtnEl.appendChild( document.createTextNode( '×' ) );
# 				closeBtnEl.setAttribute( 'type', 'button ');
# 				closeBtnEl.classList.add( 'sticky-leaderboard__close' );
# 				stickyEl.appendChild( closeBtnEl );
#
# 				// On click, hide container.
# 				closeBtnEl.addEventListener( 'click', function() {
# 					stickyEl.classList.add( 'sticky-leaderboard--hidden' );
# 				} );
# 			} );
# 		} )();
# 	</script>
# <script id="lazy-load-scripts-footer-before">( function () {
# 	window.addEventListener( 'rappler-moodmeter-js-loaded', () => {
# 		window.waitForKeycloakInit().then(() => {
# 			const pianoId = window.keycloak?.authenticated && window.keycloak.idTokenParsed?.piano_id || 'guest';
#
# 			const mm = new MoodMeter({
# 				articleId: 3044525,
# 				username: "guest",
# 				pianoId: pianoId,
# 				cxenseId: 'cxense-1',
# 				deepId: 'deep-1'
# 			});
#
# 			mm.init();
# 		})
# 	} );
# } )();</script><script id="rappler-elections-js-extra">
# var rapplerElectionData = {"dataUrl":"https:\/\/storage.googleapis.com\/phvote-prod-elc-data-2025-raw-public-production\/transmission_summary.json"};
# </script>
# <script id="rappler-elections-js" src="https://www.rappler.com/content/mu-plugins/rappler-admin/build/rappler-admin.721d636d940ce2c431bb.js?ver=721d636d940ce2c431bb"></script>
# <script id="datatables-js-js" src="https://cdn.datatables.net/v/dt/dt-2.1.7/fc-5.0.1/r-3.0.3/sc-2.4.3/datatables.min.js"></script>
# <script id="data-table-js-js" src="https://www.rappler.com/content/mu-plugins/rappler-ontology-next/inc/blocks/data-table//assets/data-table.js?ver=1729862619"></script>
# <script id="tippy-js-js" src="https://unpkg.com/@popperjs/core@2"></script>
# <script id="tippy-js-core-js" src="https://unpkg.com/tippy.js@6"></script>
# <script id="rappler-theme-script-js-before">
# rapplerThemeData = {"restBase":"https:\/\/www.rappler.com\/wp-json\/"};
# </script>
# <script async="" id="rappler-theme-script-js" src="https://www.rappler.com/content/themes/rappler/build/rappler-theme-script.2abbd5b23aa0c4ab6003.js?ver=2abbd5b23aa0c4ab6003"></script>
# <script id="rappler-keycloak-js-before">
# rapplerKeycloak = {"elements":{".masthead":"masthead--logged-in",".burger-nav":"burger-nav--logged-in"},"logout_button":"","url":"https:\/\/sso.rappler.com","realm":"rappler","client_id":"rappler-web-client"};
# </script>
# <script id="rappler-keycloak-js" src="https://www.rappler.com/content/mu-plugins/rappler-keycloak/assets/build/index.707daf09d5efd629f455.js?ver=707daf09d5efd629f455"></script>
# <script id="react-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/react.min.js?ver=18.3.1"></script>
# <script id="react-jsx-runtime-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/react-jsx-runtime.min.js?ver=18.3.1"></script>
# <script id="wp-autop-js" src="https://www.rappler.com/wp-includes/js/dist/autop.min.js?ver=9fb50649848277dd318d"></script>
# <script id="wp-blob-js" src="https://www.rappler.com/wp-includes/js/dist/blob.min.js?ver=9113eed771d446f4a556"></script>
# <script id="wp-block-serialization-default-parser-js" src="https://www.rappler.com/wp-includes/js/dist/block-serialization-default-parser.min.js?ver=14d44daebf663d05d330"></script>
# <script id="wp-hooks-js" src="https://www.rappler.com/wp-includes/js/dist/hooks.min.js?ver=2810c76e705dd1a53b18"></script>
# <script id="wp-deprecated-js" src="https://www.rappler.com/wp-includes/js/dist/deprecated.min.js?ver=e1f84915c5e8ae38964c"></script>
# <script id="wp-dom-js" src="https://www.rappler.com/wp-includes/js/dist/dom.min.js?ver=4ecffbffba91b10c5c7a"></script>
# <script id="react-dom-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/react-dom.min.js?ver=18.3.1"></script>
# <script id="wp-escape-html-js" src="https://www.rappler.com/wp-includes/js/dist/escape-html.min.js?ver=6561a406d2d232a6fbd2"></script>
# <script id="wp-element-js" src="https://www.rappler.com/wp-includes/js/dist/element.min.js?ver=cb762d190aebbec25b27"></script>
# <script id="wp-is-shallow-equal-js" src="https://www.rappler.com/wp-includes/js/dist/is-shallow-equal.min.js?ver=e0f9f1d78d83f5196979"></script>
# <script id="wp-i18n-js" src="https://www.rappler.com/wp-includes/js/dist/i18n.min.js?ver=5e580eb46a90c2b997e6"></script>
# <script id="wp-i18n-js-after">
# wp.i18n.setLocaleData( { 'text direction\u0004ltr': [ 'ltr' ] } );
# </script>
# <script id="wp-keycodes-js" src="https://www.rappler.com/wp-includes/js/dist/keycodes.min.js?ver=034ff647a54b018581d3"></script>
# <script id="wp-priority-queue-js" src="https://www.rappler.com/wp-includes/js/dist/priority-queue.min.js?ver=9c21c957c7e50ffdbf48"></script>
# <script id="wp-compose-js" src="https://www.rappler.com/wp-includes/js/dist/compose.min.js?ver=b8d54449305350b51869"></script>
# <script id="wp-private-apis-js" src="https://www.rappler.com/wp-includes/js/dist/private-apis.min.js?ver=17a2e640b653d742da6e"></script>
# <script id="wp-redux-routine-js" src="https://www.rappler.com/wp-includes/js/dist/redux-routine.min.js?ver=a0a172871afaeb261566"></script>
# <script id="wp-data-js" src="https://www.rappler.com/wp-includes/js/dist/data.min.js?ver=7c62e39de0308c73d50c"></script>
# <script id="wp-data-js-after">
# ( function() {
# 	var userId = 0;
# 	var storageKey = "WP_DATA_USER_" + userId;
# 	wp.data
# 		.use( wp.data.plugins.persistence, { storageKey: storageKey } );
# } )();
# </script>
# <script id="wp-html-entities-js" src="https://www.rappler.com/wp-includes/js/dist/html-entities.min.js?ver=2cd3358363e0675638fb"></script>
# <script id="wp-dom-ready-js" src="https://www.rappler.com/wp-includes/js/dist/dom-ready.min.js?ver=f77871ff7694fffea381"></script>
# <script id="wp-a11y-js" src="https://www.rappler.com/wp-includes/js/dist/a11y.min.js?ver=d90eebea464f6c09bfd5"></script>
# <script id="wp-rich-text-js" src="https://www.rappler.com/wp-includes/js/dist/rich-text.min.js?ver=4021b9e4e9ef4d3cd868"></script>
# <script id="wp-shortcode-js" src="https://www.rappler.com/wp-includes/js/dist/shortcode.min.js?ver=b7747eee0efafd2f0c3b"></script>
# <script id="wp-blocks-js" src="https://www.rappler.com/wp-includes/js/dist/blocks.min.js?ver=0d232d232463200f5cfd"></script>
# <script id="moment-js" src="https://www.rappler.com/wp-includes/js/dist/vendor/moment.min.js?ver=2.29.4"></script>
# <script id="moment-js-after">
# moment.updateLocale( 'en_US', {"months":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthsShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"weekdays":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"weekdaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"week":{"dow":1},"longDateFormat":{"LT":"g:i a","LTS":null,"L":null,"LL":"F j, Y","LLL":"F j, Y g:i a","LLLL":null}} );
# </script>
# <script id="wp-date-js" src="https://www.rappler.com/wp-includes/js/dist/date.min.js?ver=aaca6387d1cf924acc51"></script>
# <script id="wp-date-js-after">
# wp.date.setSettings( {"l10n":{"locale":"en_US","months":["January","February","March","April","May","June","July","August","September","October","November","December"],"monthsShort":["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sep","Oct","Nov","Dec"],"weekdays":["Sunday","Monday","Tuesday","Wednesday","Thursday","Friday","Saturday"],"weekdaysShort":["Sun","Mon","Tue","Wed","Thu","Fri","Sat"],"meridiem":{"am":"am","pm":"pm","AM":"AM","PM":"PM"},"relative":{"future":"%s from now","past":"%s ago","s":"a second","ss":"%d seconds","m":"a minute","mm":"%d minutes","h":"an hour","hh":"%d hours","d":"a day","dd":"%d days","M":"a month","MM":"%d months","y":"a year","yy":"%d years"},"startOfWeek":1},"formats":{"time":"g:i a","date":"F j, Y","datetime":"F j, Y g:i a","datetimeAbbreviated":"M j, Y g:i a"},"timezone":{"offset":8,"offsetFormatted":"8","string":"","abbr":""}} );
# </script>
# <script id="wp-primitives-js" src="https://www.rappler.com/wp-includes/js/dist/primitives.min.js?ver=aef2543ab60c8c9bb609"></script>
# <script id="wp-warning-js" src="https://www.rappler.com/wp-includes/js/dist/warning.min.js?ver=ed7c8b0940914f4fe44b"></script>
# <script id="wp-components-js" src="https://www.rappler.com/wp-includes/js/dist/components.min.js?ver=36b97398bf090476214e"></script>
# <script id="client-three-point-summary-js-extra">
# var wpServerData = {"apiRoute":"\/wp-json\/summary\/v1\/update-post-meta","postId":"3044525"};
# </script>
# <script id="client-three-point-summary-js" src="https://www.rappler.com/content/themes/rappler/build/client-three-point-summary.0c0e4935c9149705899b.js?ver=0c0e4935c9149705899b"></script>
# <script id="lazy-load-scripts-js-before">
# var lazyLoadScriptsEntries = [{"element_selectors":".container","offset":"0px","script_id":"rappler-cxense-widget-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-cxense\/build\/rappler-cxense-widget.8b26a0b2fce60e965f8c.js","script_async":false},{"element_selectors":".site-header, #burger-navigation, #rappler-comments","offset":"0px","script_id":"rappler-piano-js","script_src":"https:\/\/experience-ap.piano.io\/xbuilder\/experience\/load?aid=CS7qljxwpj","script_async":true},{"element_selectors":".site-header, #burger-navigation, #rappler-comments","offset":"0px","script_id":"rappler-piano-init-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-piano\/assets\/build\/rappler-piano-init.63b2232b1fcf4ef1068e.js","script_async":true},{"element_selectors":"#rappler-speechify","offset":"0px","script_id":"rappler-speechify-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-speechify\/assets\/build\/index.c080d8d1749e24ef271f.js","script_async":true},{"element_selectors":".latest-videos, .video-article-content-container, .youtube-video, .carousel--videos, .developing-stories__feed","offset":"100px","script_id":"rappler-youtube-js","script_src":"https:\/\/www.rappler.com\/content\/mu-plugins\/rappler-youtube\/assets\/build\/rappler-youtube.80f3d584b95ab49ef173.js","script_async":false},{"element_selectors":".dailymotion-container","offset":"800px","script_id":"rappler-dailymotion-js","script_src":"https:\/\/srvr.dmvs-apac.com\/v2\/dm-ce.min.js","script_async":false},{"element_selectors":"#moodmeter","offset":"0px","script_id":"rappler-moodmeter-js","script_src":"https:\/\/mm-widget-production.rappler.com","script_async":false}];
# </script>
# <script async="" id="lazy-load-scripts-js" src="https://www.rappler.com/content/mu-plugins/lazy-load-scripts/assets/build/main.5194775d182c57153c00.js?ver=5194775d182c57153c00"></script>
# </body>
# </html>
# <!--
# 	generated in 0.380 seconds
# 	631085 bytes batcached for 300 seconds
# -->

# %% [markdown]
# We'll extract the following information to create our corpus.
# * article link
# * article title
# * date published
# * article's text / body
# * *optional*: tags, i.e., related topic

# %% [markdown]
# ## Extract the webpage's title.

# %%
soup.title  # with HTML tags
soup.title.text  # text within the HTML tags
title = soup.title.text.strip()  # whitespaces are removed
title
# Out:
# 'Conflict in Team Duterte: Kaufman and Roque clash'

# %% [markdown]
# ## Extract the webpage's date published.

# %%
# Date published
date_published = soup.find(
  'time',  # HTML element tag
  {
      'class': 'published',
      'datetime': True
  }  # HTML attribute
)
# Actual text within the HTML element
date_published.text.strip()

# If you're after the HTML attribute, use the attribute name for the key
date_published = date_published['datetime']

date_published
# Out:
# '2025-08-01T10:00:00+08:00'

# %% [markdown]
# ## Extract the webpage's text

# %%
# Extract article text
# element: div
# class: post-single__content entry-content
article_text = soup.find(
  'div',  # HTML element tag
  {
    'class': 'post-single__content entry-content'
  }  # HTML attribute
)
# Returns the HTML code for the article
article_text

# Get all paragraph (<p>) from the article_text
tagged_lines = article_text.find_all('p')  # Return list of paragraph elements

# Removes the HTML tags
text = ''
for line in tagged_lines:
  untagged_line = line.get_text()
  text += untagged_line + '\n'

# Returns the article text as 1 big string
print(text)
# Out:
# There’s conflict brewing in The Hague, as the lead counsel of former president Rodrigo Duterte and his loyal former spokesperson traded barbs over strategies.
# It all started in June when Vice President Sara Duterte, who had just visited her father at the International Criminal Court (ICC), told supporters that former spokesperson Harry Roque had suggested “going through the Dutch laws” to get Duterte out of prison in the interim.
# “One of the discussions which was one of your suggestions, Spokes, to go through the Dutch laws — which he said okay, you explore that. And sabi ko (and I said) I can do that while I’m in the Philippines,” the Vice President said on June 3.
# It turns out that this suggestion entailed suing the Dutch government for what they claimed was a case of extraordinary rendition. This is a term in international law which alleges that the transfer to a foreign state of a person was illegal, and a case of abduction. The Philippine government said it was following a domestic law, RA 9851 or the International Humanitarian Law (IHL), under which a person wanted by an international court can be surrendered.
# “Inexplain ko kung ano ‘yung teorya na ang karapatang pantao ay obligasyon ng mga estado kasama na ang Netherlands na ipagtanggol at itaguyod kasama na diyan ‘yung karapatan sa due process ni Tatay Digong na nalabag nung siya nga ay kinidnap,” Roque said over his livestream on Thursday, July 31.
# (I explained my theory that states, including the Netherlands, have an obligation to defend and uphold human rights, including Duterte’s rights to due process, which was violated when he was kidnapped.)
# Kaufman said this was a “crazy scheme” and told a supporter based in The Hague that “neither the former president, nor anyone else in his immediate vicinity, is interested in Harry Roque as a lawyer.”
# Roque maintained that his exploration of this option was authorized by the Duterte family, telling Rappler on Thursday that: “VP confirmed that PRRD approved. She said so in a briefing after one of her visits.”
# “The Vice President always defers to me and my team on all legal matters concerning her father. We are too busy working to sustain Harry Roque’s thirst for attention by commenting on his unsolicited and harebrained schemes,” Kaufman told Rappler on Thursday.
# Rappler reached out to the camp of the Vice President for comment, but we have yet to receive a response. We will update this story once we do.
# Roque is seeking asylum in The Netherlands, claiming he is a victim of persecution. There is a Philippine warrant of arrest out for him for qualified human trafficking over his role as a lawyer for the alleged owners of the raided scam hub in Porac, Pampanga.
# Kaufman has asked for interim release and has also filed a jurisdictional challenge, but he recently asked the ICC pre-trial chamber to not rule on those requests just yet. Kaufman said he had just obtained “essential” information that would be crucial to those requests. He also hinted at the possibility of asking for a suspension of the September 23 confirmation of charges hearing.
# Victims and the prosecution have hit the delays for being inefficient and prejudicial.
# – Rappler.com

# %% [markdown]
# ## Combine features into dataframe

# %%
# Link
# Title
# Date Published
# Article's Text
rappler = pd.DataFrame(
    columns=['title', 'link', 'date_published', 'text']
)
doc_details = [title, link, date_published, text]
rappler.loc[len(rappler)] = doc_details
rappler
# Out:
#                                                title  \
# 0  Conflict in Team Duterte: Kaufman and Roque clash
#
#                                                 link  \
# 0  https://www.rappler.com/newsbreak/inside-track...
#
#               date_published  \
# 0  2025-08-01T10:00:00+08:00
#
#                                                 text
# 0  There’s conflict brewing in The Hague, as the ...

# %% [markdown]
# ## Export to Excel file

# %%
try:
  # Google Colab
  from google.colab import drive  # type: ignore
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/rappler.xlsx'
except:
  # VS Code / Local machine
  file_name = 'rappler.xlsx'

rappler.to_excel(file_name)
print(f'File saved to {file_name}')
# Out:
# File saved to rappler.xlsx

# %% [markdown]
# ## Function `extract_article_data`

# %%
# Extract data from article based on link
def extract_article_data(link):
  """
  Extracts data from an article based on the provided link.

  Parameters:
    link (str): The URL of the article.

  Returns:
    list: A list containing the extracted article details in the following order:
      - title (str): The title of the article.
      - date (str): The date the article was published.
      - link (str): The URL of the article.
      - text (str): The content of the article.
  """
  # Make a GET request for the article URL
  r = requests.get(link, headers=headers)

  # Parse the HTML
  soup = BeautifulSoup(r.content, 'html.parser')

  # Retrieve doc title
  title = soup.title.text.strip()

  # IF NOT WITH RAPPLER ARTICLE, CHANGE THIS XOXO
  # Retrieve doc date
  date = soup.find("time", {"datetime": True})['datetime']

  # IF NOT WITH RAPPLER ARTICLE, CHANGE THIS XOXO
  # Retrieve article content
  text = ''
  tagged_lines = soup.find("div", {"class": "post-single__content entry-content"}).find_all('p')
  for line in tagged_lines:
    untagged_line = line.get_text()
    text += untagged_line + '\n'

  # Create list containing doc details
  # Append to dataset
  doc_details = [title, link, date, text]
  return doc_details

# %%
# Test the `extract_article_data` function
rappler.loc[len(rappler)] = extract_article_data(
  'https://www.rappler.com/philippines/duterte-lawyer-nicholas-kaufman-meeting-icc-prosecutor-karim-khan-israel/'
)
rappler
# Out:
#                                                title  \
# 0  Conflict in Team Duterte: Kaufman and Roque clash
# 1  Meeting with ICC prosecutor about Duterte, Isr...
# 2  Meeting with ICC prosecutor about Duterte, Isr...
#
#                                                 link  \
# 0  https://www.rappler.com/newsbreak/inside-track...
# 1                          2025-07-17T09:42:59+08:00
# 2  https://www.rappler.com/philippines/duterte-la...
#
#                                       date_published  \
# 0                          2025-08-01T10:00:00+08:00
# 1  https://www.rappler.com/philippines/duterte-la...
# 2                          2025-07-17T09:42:59+08:00
#
#                                                 text
# 0  There’s conflict brewing in The Hague, as the ...
# 1  MANILA, Philippines – Nicholas Kaufman, the le...
# 2  MANILA, Philippines – Nicholas Kaufman, the le...

# %% [markdown]
# ## Extracting Multiple Articles

# %%
# mother_url = 'https://www.rappler.com/topic/philippine-offshore-gaming-operations/page/'

mother_url = "https://www.rappler.com/wp-json/rappler/v1/ontology-topics/2653059/latest-news?page="
page = 1
page_limit = 5
corpus = pd.DataFrame(columns=['title', 'link', 'date_published', 'text'])

while True:
  # Convert page number as a string
  page_str = str(page)
  # Form the article page
  page_url = mother_url + page_str
  print('\nWorking on ' + page_url)

  # Add random time between 1 to 5 seconds before requesting
  time.sleep(random.randint(1, 5))

  # # Get the list of articles within the page
  page_r = requests.get(page_url, headers=headers)

  # Check if page request is 200
  if page_r.status_code != 200:
    print('Failed to retrieve page')
    break

  # Check if the response contains valid JSON
  try:
    page_data = page_r.json()
  except ValueError:
    print('Failed to parse JSON')
    break

  # Go through each article to extract and save to the dataframe
  for article in page_data:
    # Focus on the article permalink, skip article if no 'permalink' found
    if 'permalink' not in article:
      continue
    article_link = article['permalink']

    # Clean up article_link
    article_link = article_link.replace('\\/', '/')

    # For each articles, invoke `extract_article_data`
    try:
      # Append to a dataframe
      tmp = extract_article_data(article_link)
      print(tmp)
      corpus.loc[len(corpus)] = tmp
    except:
      # if there's an extraction error, skip
      continue

  # Check whether you have reached the page limit
  if page >= page_limit:
    break

  # Go to the next page
  page += 1
# Out:
# Working on https://www.rappler.com/wp-json/rappler/v1/ontology-topics/2653059/latest-news?page=1
# ["Hindi Ito Marites: The Hague and Filipinos' pursuit of justice", 'https://www.rappler.com/newsbreak/podcasts-videos/video-hindi-ito-marites-hague-filipinos-pursuit-justice/', '2025-08-15T16:00:29+08:00', 'When local courts offer no refuge, or when faced with a formidable foreign adversary, Filipinos have, in recent history, turned to two institutions based in the same city: The Hague in the Netherlands.\nThe international tribunal that in July 2016 ruled in favor of the Philippines in a pleading against China, concerning the West Philippine Sea, was housed in the Permanent Court of Arbitration, whose headquarters is the Peace Palace. Now, former president Rodrigo Duterte is detained in the premises of the International Criminal Court, where he awaits trial for crimes against humanity for his brutal drug war.\nRappler editor-at-large Marites Vitug takes us on a visual tour of these places that witnessed turning points in recent Philippine history. – Rappler.com\nPresenter, writer: Marites VitugProducer: JC GotingaVideo editor: Emerald HidalgoVideographer: Jeff DigmaSupervising producer: Beth Frondoso\n']
# ['FACT CHECK: No Guinness record of Duterte as ‘most loved detainee in world history’', 'https://www.rappler.com/newsbreak/fact-check/no-guinness-record-rodrigo-duterte-most-loved-detainee-world-history/', '2025-08-12T10:00:00+08:00', 'Claim: Former president Rodrigo Duterte holds a Guinness World Record as the “most famous and most loved detainee in world history.”\nWhy we fact-checked this: The TikTok video containing the claim has 122,400 views, 3,807 likes, 156 comments, and 161 shares as of writing.\nThe video features a photo of Duterte overlaid with text stating, “Most famous and most loved detainee in world history. Philippines’ Duterte in ICC jail, chaos outside. Guinness Book by Hassan Mati.”\nSome Filipinos appeared to believe the claim, with several even expressing pride that Duterte’s detention at the International Criminal Court (ICC) had supposedly boosted the court’s global popularity, with comments suggesting it had become a “tourist attraction” because of his presence.\nThe facts: There is no Guinness World Record entry naming Duterte as the “most famous and most loved detainee in world history.” Guinness has no official category for such a title, as it does not recognize records based on subjective variables like f
# ['Duterte team wants Prosecutor Khan disqualified for conflict of interest', 'https://www.rappler.com/philippines/duterte-defense-request-disqualify-prosecutor-karim-khan-conflict-interest/', '2025-08-08T07:00:00+08:00', 'MANILA, Philippines – Prosecutor Karim Khan, on leave from the International Criminal Court (ICC), supposedly once represented victims of the war on drugs as a private lawyer, which is being used now as a ground to disqualify him from the crimes against humanity case against former president Rodrigo Duterte.\n“This request to disqualify Mr Khan is grounded in an irreconcilable conflict of interest arising out of his former….representation of….victims of an alleged policy of extra-judicial drug-related killings in the Philippines and his subsequent role as Chief ICC Prosecutor, charged with overseeing a fair and impartial investigation of that very same policy of killing,” said the request filed on Thursday, August 7, by Duterte’s defense counsel Nicholas Kaufman.\nOne of the unique features of the ICC is that the prosecutor is tasked to find both incriminating and exculpatory evidence against the suspect. Under Article 54 of the Rome Statute, the prosecutor must investigate “incriminating and exonerating circumstances equally,” or to find evidence that would pin the suspect down, or clear them, all in the name of finding out the truth.\n“This, of course, suggests a proactive duty to search for exculpatory information,” said Kaufman, adding that exculpatory evidence, which would favor Duterte, would go against the interest of the victims of the war on drugs, some of whom he had represented before.\n“This conflation of roles, leading to a blatant conflict of interest, is precisely what Rule 34(1)(b) seeks to prevent,” said Kaufman.\nKaufman cited the ICC’s Rules of Procedure and Evidence, under which grounds to disqualify a prosecutor include “involvement, in his or her private capacity, in any legal proceedings initiated prior to his or her involvement in the case, or initiated by him or her subsequently, in which the person being investigated or prosecuted was or is an opposing party.”\nMuch of the details of this supposed representation have been redacted. As declared in his curriculum vitae, Khan was a human rights course trainer in February 2018 for the Commission on Human Rights (CHR). His predecessor, Fatou Bensouda, has already started preliminary examination of the war on drugs by that time.\nAccording to Kaufman’s request, Khan first declared this previous involvement on March 6, 2025, or a month after he requested for a warrant of arrest against Duterte. The warrant was approved on March 7, and Duterte was arrested in Manila on March 11.\nKaufman said that this information was only disclosed to them on June 27.\n“Counsel then engaged in lengthy inter partes communications with the Prosecution in an attempt to discern the full scope of Mr Khan’s former involvement [REDACTED] as victims’ representative; the Prosecution declined to respond to all of Counsel’s questions,” said Kaufman.\nKaufman is relying on an appeals chamber findings in a separate case, where Khan’s disqualification is also being sought, that the standard is not actual lack of impartiality but whether it “reasonably appears that the Prosecutor lacks impartiality.”\n“Mr Khan relied on information obtained while defending the independent interests of the victims to support actions falling under an entirely separate mandate — one that also carries the obligation to disclose exculpatory evidence,” said Kaufman.\nCHR Chairperson Richard Palpal-latoc told Rappler that available records show that “the CHR had no part in the activities of ICC Prosecutor Khan with the drug war victims prior to his appointment.”\n“Also, I cannot say, due to lack of official records, if the former members had prior dealings with him in their respective personal or individual official capacity,” Palpal-latoc told Rappler in a\xa0 text message on Monday, August 11. ...
#
# Working on https://www.rappler.com/wp-json/rappler/v1/ontology-topics/2653059/latest-news?page=2
# ['FACT CHECK: ICC did not sentence Duterte to reclusion perpetua', 'https://www.rappler.com/newsbreak/fact-check/icc-not-sentenced-rodrigo-duterte-reclusion-perpetua/', '2025-08-04T11:30:00+08:00', 'Claim: The International Criminal Court (ICC) sentenced former Philippine president Rodrigo Duterte, who faces crimes against humanity charges over alleged extrajudicial killings under his administration, to reclusion perpetua.\nWhy we fact-checked this: The TikTok video containing
e that Duterte was dying. By this time, DDS were flooding social media networks with AI-generated images of skin-and-bones Duterte.\nWhen DDS flood social media with fake news and memes, there is a purpose. Death in Filipino culture is a phenomenon that draws sympathy. The time became ripe to elicit the Filipino sense of compassion on the Duterte issue. It was time to exploit the idea to return him to the Philippines as part of the “interim release” the family requested, but which as of this writing, has not been responded to by the three judges of the ICC pre-trial chamber 1.\nEnter senator Alan Peter Cayetano. There is only one thing to take note of Cayetano — he is a lawyer unlike Padilla. But like Padilla, he too, if we may name-call his affiliation, is also a DDS.\nOn July 10, Cayetano filed a Senate resolution calling for the “Interim Release of Former President Rodrigo Roa Duterte (FPRRD), Including Inter Alia Entering Into an Arrangement with the ICC to Receive Custody of FPRRD in a Form of House Arrest or Any Other Appropriate Arrangement In the Premises of the Philippine ...
# ...
#
# Working on https://www.rappler.com/wp-json/rappler/v1/ontology-topics/2653059/latest-news?page=5
# ['Duterte is now finding out who the witnesses are against him in the ICC', 'https://www.rappler.com/philippines/duterte-finding-out-witnesses-icc-disclosure-july-2025/', '2025-07-10T08:15:34+08:00', 'MANILA, Philippines – With two and a half months to go before the confirmation of charges hearing, former president Rodrigo Duterte is now finding out who the witnesses are against him in the International Criminal Court (ICC), the effect of which may include “increased threat on witnesses and victims.”\nUnder ICC rules, the prosecution needs to gradually disclose its evidence to the defense team. The prosecution had wanted an extension to disclose this citing “risk to their personal safety and well-being. “Prosecution presently anticipates being in a position to disclose the identities of all existing witnesses by 1 July 2025,” it said last May.\nRecords show that the prosecution indeed disclosed evidence to the defense on July 1. Types of evidence that need to be disclosed to Duterte are those incriminating to him, and even those that can exonerate him.\nThe July 1 disclosure is the most recent, and it included incriminating evidence against Duterte relating to three murder incidents: one allegedly killed by the Davao Death Squad when Duterte was mayor; the second allegedly killed in barangay operations or the so-called low-level targets when he was president during the drug war; and the third was allegedly a high-value target also during his presidency.\nWe know at least from the communications that some of the killed high-value targets made known to the ICC prosecutor were Albuera, Leyte mayor Rolando Espinosa Sr who was killed inside his jail cell in November 2016, and Ozamiz City mayor Reynaldo Parojinog\xa0who was killed with 14 others in a police raid in July 2017.\n“The general rule is that the identities and statements of the witnesses to these murders are disclosed to the Defense, so we have to assume that this happened in this recent disclosure,” said Joel Butuyan, an ICC-accredited counsel who represents a group of drug war victims.\n“So yes, there is an increased threat on witnesses and victims, because there is always the danger that their identities may be leaked, despite strict obligations to maintain confidentiality,” said Butuyan.\nIncidentally, Vice President Sara Duterte said in an interview from The Hague on July 7 that she can show proof that some of the evidence against her father were obtained through harassment. “At ‘yung ibang ebidensiya nila, meron din tayong ebidensiya na kinuha ‘yun by force or intimidation or harassment, so makikita rin natin ‘yun soon, very soon,” she said. (We have evidence that they obtained other evidence by force or intimidation or harassment, so we will also see that soon, very soon.)\nThe prosecution continues to gather additional evidence even as they are already disclosing existing ones. They were reminded by the pre-trial chamber last April that they “shall conduct its investigative activities in a way that will not affect the disclosure process or the conduct of the confirmation of charges proceedings and hearing.”\nThere’s been some tense exchanges between the prosecution and the defense teams in the last filings, which were related to the prosecution “strongly opposing” Duterte’s request for an interim release.\nDuterte’s lead defense lawyer Nicholas Kaufman had initially written that the prosecution will not oppose the request, but this was belied by the prosecution. It turns out the prosecution only agreed to an interim release to their chosen country, and not to Duterte’s chosen country or any other country.\nKaufman is now seeking permission to respond to the prosecution’s latest position, and claimed that it was “clear” to both parties that as long as the conditions are as strict, the prosecution would be amenable to another country. Kaufman called out the prosecution as acting “disingenuously” and making a “volte-face.”\nThis claim is “not credible,” said the pros ...
# ['Hustle Hassle: 10,436km goal', 'https://www.rappler.com/hustle/hassle-10436km-goal/', '2025-07-08T17:52:25+08:00', '']
# ["FACT CHECK: No ICC judges removed from Duterte's case", 'https://www.rappler.com/newsbreak/fact-check/no-icc-judges-removed-rodrigo-duterte-case/', '2025-07-08T16:00:00+08:00', 'Claim:\xa0Four International Criminal Court (ICC) judges have been removed as magistrates in\xa0former president Rodrigo Duterte’s\xa0ongoing case.\nWhy we fact-checked this:\xa0The TikTok video containing the claim has 6,811 views, 451 likes, 21 shares, and 88 comments as of writing.\nText in the video states:\xa0“Excited na ba lahat ng DDS (Diehard Duterte Supporters)? Tanggal na ang apat na judge.”\n(Are all the DDS excited? Four judges have been removed.)\nSome Filipinos appeared to believe the claim, posting comments thanking God for supposedly blessing Duterte. One of the top-liked comments reads, “Grabe ang power sa Panginoon… palatandaan ito na tinulungan ni Lord si Tatay D.”\n(God’s power is amazing… This is the sign that the Lord helped Father [Duterte].)\nThe facts:\xa0There is no official statement or update from the ICC confirming the removal of any judges involved in hearing Duterte’s case. The ICC’s Pre-Trial Chamber I, composed of Presiding Judge Iulia Motoc of Romania, Judge Reine Adélaïde Sophie Alapini-Gansou of Benin, and Judge Socorro Flores Liera of Mexico, is handling the former president’s crimes against humanity case. (READ:\xa0Who are the all-women ICC judges who ordered Duterte’s arrest?)\nThe false information likely stems from Duterte’s request to disqualify Judges Alapini-Gansou and Flores Liera from hearing his case over the possibility of “perceived bias” due to their prior rulings affirming the\xa0ICC’s jurisdiction\xa0over the Philippines. This request was\xa0unanimously rejected\xa0by the ICC’s plenary of judges in a decision dated June 9, and by\xa0all 18 judges\xa0of the ICC in a 13-page decision released on July 3.\nAccording to the ICC, the judges acted fully within their mandate under Article 15(4) of the\xa0Rome Statute, which empowers pre-trial chambers to authorize investigations if there is reasonable basis and jurisdiction. The Court stressed that prior involvement in procedural matters does not disqualify a judge from continuing on the case, and it found\xa0no actual or reasonable apprehension of bias.\xa0\nICC detention:\xa0Duterte remains\xa0detained\xa0at the ICC Detention Center in The Hague, Netherlands, following his arrest last March over charges of\xa0crimes against humanity\xa0linked to the thousands of killings in his administration’s\xa0war on drugs.\xa0\nDuterte’s legal team has requested\xa0interim release\xa0on humanitarian grounds, citing his advanced age and a foreign state’s willingness to receive him under court-imposed conditions.\xa0\nHowever, the ICC prosecution has\xa0strongly opposed\xa0the motion. In the prosecution’s filing, they argue that Duterte poses a serious flight risk, could obstruct the ongoing investigation, and may commit further crimes if released.\xa0\nThe ICC is set to hold
# ['Join our community chat: Mindanao pulse on possible trials of Sara and Rodrigo Duterte', 'https://www.rappler.com/moveph/community-chat-mindanao-pulse-impeachment-icc-trial-july-10/', '2025-07-04T19:20:38+08:00', 'MANILA, Philippines – Duterte stronghold Mindanao is the region that has consistently given Vice President Sara Duterte and her father, former president Rodrigo Duterte, their highest approval ratings.\nBut what do Mindanaoans think of the two Dutertes, their most controversial political figures, possibly facing major trials in the coming months?\nThe Vice President may face an impeachment trial when the 20th Congress begins in late July. The former president, currently detained in the Netherlands, may face the International Criminal Court for alleged crimes against humanity.\nSeeking the pulse of the Dutertes’ home region, Rappler journalists have partnered with Ateneo de Davao University and the Movement Against Disinformation for a community chat on July 10, at 11 am in the \xa0Philippine Politics chat room.\xa0\nThe community chat will feature professor Neil Ryan Pancho and lawyer Meong Cabarde of the Ateneo de Davao University-Political Science and History Department, and lawyer Ernesto Neri of Movement Against Disinformation (MAD), as resource persons.\xa0\nThe chat will be moderated by Rappler Mindanao bureau coordinator Herbie Gomez and reporter Jairo Bolledo.\nThe chat is open for everyone. To join via desktop, click this link. Another way is to download the Rappler app for free, tap the Community tab, and join the Philippine Politics chat room there.\nThe Rappler app is available on both App Store and Play Store.\xa0\nYou can join as many chat rooms as you want, based on your interest, and get useful notifications on breaking news and Rappler’s top stories. See you in the chat rooms! — Rappler.com\n']

# %%
try:
  # Google Colab
  from google.colab import drive  # type: ignore
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/rappler_corpus.xlsx'
except:
  # VS Code / Local machine
  file_name = 'rappler_corpus.xlsx'

corpus.to_excel(file_name)
print(f'File saved to {file_name}')
corpus
# Out:
# File saved to rappler_corpus.xlsx
#                                                 title  \
# 0   Hindi Ito Marites: The Hague and Filipinos' pu...
# 1   FACT CHECK: No Guinness record of Duterte as ‘...
# 2   WATCH: Tuloy ba ang pre-trial hearing ni Duter...
# 3   Duterte team wants ICC Prosecutor Khan disqual...
# 4   Duterte team wants Prosecutor Khan disqualifie...
# 5   FACT CHECK: ICC did not sentence Duterte to re...
# 6   FACT CHECK: Photo of barong-clad Duterte insid...
# 7   Kaufman, Roque clash over defense strategy for...
# 8   FACT CHECK: ICC deferred decision on Duterte i...
# 9   Conflict in Team Duterte: Kaufman and Roque clash
# 10  Drug war victims, prosecution slam ‘delays’ in...
# 11  Victims, prosecution hit 'delay' in ICC procee...
# 12  FACT CHECK: World leaders didn’t meet in The H...
# 13         [WATCH] Explainer: Si Duterte sa The Hague
# 14  Federal judge blocks enforcement of Trump's or...
# 15  Meeting with ICC prosecutor about Duterte, Isr...
# 16  [The Slingshot] The marcha funebre that wasn’t...
# 17  Marcos-Duterte feud, geopolitics making media ...
# 18  FACT CHECK: ‘Skin and bones’ photo of Duterte ...
# 19  From the belly of the beast: Thought leaders s...
# 20  Duterte is now finding out who the witnesses a...
# 21                       Hustle Hassle: 10,436km goal
# 10  Here are today’s headlines – the latest news i...
# 11  MANILA, Philippines – Victims of the drug war ...
# 12  Claim: A photo shows world leaders gathered in...
# 13  MANILA, Philippines – Naka-schedule humarap si...
# 14  WASHINGTON, DC, USA – A federal judge blocked ...
# 15  MANILA, Philippines – Nicholas Kaufman, the le...
# 16  Who started the talk that Rodrigo Duterte was ...
# 17  Early this month, SeaLight, which monitors Chi...
# 18  Claim: Former president Rodrigo Duterte, who i...
# 19  MANILA, Philippines — For decades, the Duterte...
# 20  MANILA, Philippines – With two and a half mont...
# 21
# 22  Claim: Four International Criminal Court (ICC)...
# 23  Claim: Former president Rodrigo Duterte is set...
# 24  MANILA, Philippines – Duterte stronghold Minda...

# %% [markdown]
# # Method 2: Using the YouTube API

# %% [markdown]
# ## Create YouTube Data API v3 key

# %% [markdown]
# Before we can scrape data from YouTube, we need to get an API key. APIs, or Application Programming Interfaces, are ways in which two applications (e.g., Google Colaboratory and YouTube) can talk to each other. You can think of it as the language through which two apps can speak so they can send and receive information from each other.
#
# Some apps (e.g., YouTube and Google services) require an API key, or a string of characters that authenticates a user to access the app through an API.

# %% [markdown]
# 1.   To get your API key, head to https://console.cloud.google.com/cloud-resource-manager
# 2.   Click on Create Project, name the project "YouTube scraping," and press "CREATE"
# 3.   In your Google Developers Console dashboard, click the Navigation Menu (the three lines) at the upper left corner and select "APIs & Services"
# 4.   When prompted, select the "YouTube scraping" project
# 5.   You will be directed to the project's dashboard, where you are to click "Explore & Enable APIs"
# 6.   Search for and select "YouTube Data API v3"
# 7.   Enable the API and click "Create Credentials"
# 8.   Select "public data" when asked what kind of data you will access
# 9.   Find your API key at the "Credentials" tab on the left side of your dashboard (If it's not there, just click "Create Credentials" again and select "API key")

# %% [markdown]
# Now, we import the pertinent packages.
#
# `build` creates a resource object that uses the API key to communicate with YouTube.

# %%
import pandas as pd
from googleapiclient.discovery import build

# %%
api_key = 'AIzaSyArJa4h3CPtJILqexIrRWL22W7K1ZzxABs'
youtube = build('youtube', 'v3', developerKey=api_key)

# %% [markdown]
# Let's make it our goal to make a corpus based on YouTube comments about Alice Guo.
# Let's start with this link: https://www.youtube.com/watch?v=yfoq-0gGTLM

# %% [markdown]
# To get comment thread results from YouTube, we execute the code below that uses the `commentThreads()` and `list` methods with two arguments:
# *   `id`, which we get from the link above
# *   `parts`, which we set as "snippet,replies" because these are the only parts of the comment results we are interested in
#
# To learn more about how to use the YouTube API to get comment thread results, refer to https://developers.google.com/youtube/v3/docs/commentThreads/list

# %% [markdown]
# Now, let's try and look at the contents of the video_response object.

# %% [markdown]
# ## Extract the YouTube comments

# %%
video_id = 'xPb4FMfGbos'
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time'
).execute()
video_response
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'ewHWdkDSbiv0bp1sCDqRRZQlsG4',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJZ2dHQUFTQlFpSklCZ0FFZ1VJblNBWUFSSUZDSWNnR0FBU0JRaW9JQmdBSWc0S0RBakg5UFMtQmhDUXd1VFVBdw==',
#  'pageInfo': {'totalResults': 50, 'resultsPerPage': 50},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': '3QTe6t3GBHw3uoh678KrcC8yCeg',
#    'id': 'UgxKqA6e6cbuxrTcN854AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'yb-SxNKCYpBxFlt_X-QqnEYh2As',
#      'id': 'UgxKqA6e6cbuxrTcN854AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Sept 23, 2026',
#       'textOriginal': 'Sept 23, 2026',
#       'authorDisplayName': '@farinyeshar.697',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/Ga_lioy2Mz_mMDHcIwTOqgyFKysK2XbBSWbv39XxvbyvN1d69qoEKGLEmKZT4kRvldaRwMy8EQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@farinyeshar.697',
#       'authorChannelId': {'value': 'UCYR1Gq2JNC9w_ur6ChxOJAg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-08-07T14:01:01Z',
#       'updatedAt': '2025-08-07T14:01:01Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'YcvchednzNXtYG-idXXy-eSwlGk',
#    'id': 'Ugz8ynxCBwSFu3w-XKt4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '9E0yxz2NihydXlUkR0Le9yX7zdc',
#      'id': 'Ugz8ynxCBwSFu3w-XKt4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'When Digong said to the Police who carried his EJK orders. I will be responsible for you and take a fall even if I rot in jail. Apparently he didn’t know what he was talking about. It is easy to said than done. Once a man walk in to the prison. The will of a man will be tested. Until it sink in that you will be there for a long time. Prison wall will break you down,<br>Loneliness, depression, you name it. Now Digong, show your toughness. Or your weakness takes over your life',
#       'textOriginal': 'When Digong said to the Police who carried his EJK orders. I will be responsible for you and take a fall even if I rot in jail. Apparently he didn’t know what he was talking about. It is easy to said than done. Once a man walk in to the prison. The will of a man will be tested. Until it sink in that you will be there for a long time. Prison wall will break you down,\nLoneliness, depression, you name it. Now Digong, show your toughness. Or your weakness takes over your life',
#       'authorDisplayName': '@KimoSawe-n3i',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/tkXFIFiEKsOfTMEmJWbhzt-aP0ZZlYjbgBjo0l79hzYNbrAXjAYvCUjAncfk9iqqDDfXOAHpsg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@KimoSawe-n3i',
#       'authorChannelId': {'value': 'UCZkGF2oREr4KRgDFNn7heHA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-08-03T20:45:50Z',
#       'updatedAt': '2025-08-03T20:45:50Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7fEuGUFPEJ4rSOGkigTR6C22osM',
#    'id': 'Ugy88d5xbehgD7b97e54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'HfndvGfxfjNPUZ1Ai8SIGyUCt4E',
#      'id': 'Ugy88d5xbehgD7b97e54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'ang tapang nuong hindi pa naaresto..dalian daw ng ICC kasi sisipain nya..nuong nasa Hague na parang  nasipa ng kabayo.nagpapaawa na magsalita..parang bata na me lagnat gusto lang ng skyflakes at tru-ornage.. LOL',
#       'textOriginal': 'ang tapang nuong hindi pa naaresto..dalian daw ng ICC kasi sisipain nya..nuong nasa Hague na parang  nasipa ng kabayo.nagpapaawa na magsalita..parang bata na me lagnat gusto lang ng skyflakes at tru-ornage.. LOL',
#       'authorDisplayName': '@nameless5769',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n1sJD2NxxBE3rN6TcTcXJNRR2g55Ar3TcpNxtL34aLnQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@nameless5769',
#       'authorChannelId': {'value': 'UC_LFFUdldv8RQTLAZkmTk3w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-08-01T07:29:49Z',
#       'updatedAt': '2025-08-01T07:29:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zM_CB1gOfS3S6qEoTpbsQde9kT0',
#    'id': 'Ugx5n-UZv4nX5hkSfxt4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'K6r6AXJ1WHoCgFx6ieBNx-7ReHg',
#      'id': 'Ugx5n-UZv4nX5hkSfxt4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Life in prison please. <a href="UCkszU2WH9gy1mb0dV-11UJg/hcIfY57lBJXp6AKBx4CoCA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/ssIfY7OFG5OykQOpn4CQCw"></a>',
#       'textOriginal': 'Life in prison please. ',
#       'authorDisplayName': '@RS-fs7dw',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_l9cGMGOl-li_ak2P3XY1zp80uG7dVYtVZvOBARpLg8d-c=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RS-fs7dw',
#       'authorChannelId': {'value': 'UCx1QWPc-ddLMEX702iI02uA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-07-25T22:06:40Z',
#       'updatedAt': '2025-07-25T22:06:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'PI5twE_9IelwiKJ5eykVnOcDcLY',
#    'id': 'UgxYCDudWaEnA8ZafoB4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'B2_ylB5sL73gklwu6yhOYUgM5ww',
#      'id': 'UgxYCDudWaEnA8ZafoB4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Galing mag drama ni digong',
#       'textOriginal': 'Galing mag drama ni digong',
#       'authorDisplayName': '@marlowedeocampo4257',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mDWkdYqTiBDpwWuCJ3OiUalxW52QTlZOnBJPuvpX3Qs8U=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@marlowedeocampo4257',
#       'authorChannelId': {'value': 'UCBw-oAarQEPMM814u5I9sEQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-07-10T14:28:05Z',
#       'updatedAt': '2025-07-10T14:28:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'O-uq1045I2BE8GC8BCwjHQMRWJE',
#    'id': 'UgzSLi0fgpaIpXepI8t4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'iW4yztLOSSl8b2s_uusmqBOaiiU',
#      'id': 'UgzSLi0fgpaIpXepI8t4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Pilipino ako duterti ako si allan gaTmaitan',
#       'textOriginal': 'Pilipino ako duterti ako si allan gaTmaitan',
#       'authorDisplayName': '@Allangatmaitan-v7q',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzf_38osY0eh7aPQbfKu6wRof-DTAs7pSaNm9ZMqGPUJFfWyS5SFzzSHFBOz2qGsV8gw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Allangatmaitan-v7q',
#       'authorChannelId': {'value': 'UC11obwX1h6z5eJVNTVA1NBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-07-06T02:33:33Z',
#       'updatedAt': '2025-07-06T02:33:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'w-bLBviMW6O5qtQHhxmImGqNH00',
#    'id': 'Ugwk0W4enZB614-q1qp4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ZAdH8XgyGU8b3tfEfIGijoiBE4s',
#      'id': 'Ugwk0W4enZB614-q1qp4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Ply gus wag yong kame ioababoy duterti melmnidina poro nana ang dala niyo ako to allan gatamitan ., ayaw ko pomatan nang manga salop poro baboy ang karamihan na tao .,',
#       'textOriginal': 'Ply gus wag yong kame ioababoy duterti melmnidina poro nana ang dala niyo ako to allan gatamitan ., ayaw ko pomatan nang manga salop poro baboy ang karamihan na tao .,',
#       'authorDisplayName': '@Allangatmaitan-v7q',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzf_38osY0eh7aPQbfKu6wRof-DTAs7pSaNm9ZMqGPUJFfWyS5SFzzSHFBOz2qGsV8gw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Allangatmaitan-v7q',
#       'authorChannelId': {'value': 'UC11obwX1h6z5eJVNTVA1NBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-07-06T02:31:23Z',
#       'updatedAt': '2025-07-06T02:31:23Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '04b-4GKBwSRHsDSyCXgsk_DCri0',
#    'id': 'UgwBf9b9uOpCYbZcDGJ4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'fqKduBQbefGQ0eqASHMZ2xr5kdw',
#      'id': 'UgwBf9b9uOpCYbZcDGJ4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'I think this ICC thing looks inaccurate, because their pronunciation of the last name is completely wrong. Instead of Mr. Du-TER-te, they say Mr. Du-TERT, which is wrong! You can&#39;t have two syllables sounding the same as three syllables! ICC, fix your pronunciation! 😂😂😂',
#       'textOriginal': "I think this ICC thing looks inaccurate, because their pronunciation of the last name is completely wrong. Instead of Mr. Du-TER-te, they say Mr. Du-TERT, which is wrong! You can't have two syllables sounding the same as three syllables! ICC, fix your pronunciation! 😂😂😂",
#       'authorDisplayName': '@philippinegovernment1',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/x7QM-v7Vi-RkD9DnwCu6Vz_Ybp7ChXhYXKdXNXVqmTGM5YEvz3-KnvjAeWew3fSXnI32xJ4T9gQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@philippinegovernment1',
#       'authorChannelId': {'value': 'UCLl0Hxobnxw5wjKOrcD1PPQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-06-28T13:24:11Z',
#       'updatedAt': '2025-06-28T13:24:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'ECJ621oxrPQxI0ica4PoTz90w_U',
#    'id': 'UgydByQHyLtWf605Wd54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'SbEktYV_kTmccLTM7ROIl_TKlvw',
#      'id': 'UgydByQHyLtWf605Wd54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'For a french judge, that judge hair is a bit unkempt 🤔. Ive been in a bad day myself luckily im bald😳. Look at that hair, its sticking out everywhere🤔. Highly unusual for a french judge😳',
#       'textOriginal': 'For a french judge, that judge hair is a bit unkempt 🤔. Ive been in a bad day myself luckily im bald😳. Look at that hair, its sticking out everywhere🤔. Highly unusual for a french judge😳',
#       'authorDisplayName': '@christophertadeo6120',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/S07CrsKyt2xSPdIykVlrAfvVJ2csSoXNGpDRzzF6FXcvNWYnwm7AxhT3RRnacbl3Bu9xL54=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@christophertadeo6120',
#       'authorChannelId': {'value': 'UCvlMimXRmtjraIaqf1mnj0w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-05-11T03:15:44Z',
#       'updatedAt': '2025-05-11T03:18:15Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'bJct0LHrIh5q4nU34YRyGy62nZY',
#    'id': 'UgwXd8Qn4z3P81--76p4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '6dxSRc2QViaYE2BaNWExhMViPE4',
#      'id': 'UgwXd8Qn4z3P81--76p4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'THE PHILLIPPINNES Govermennt Is Sourounded be A couroutpDectetor Goverment  The Marcose GOVERMENTAdmenistration Will do there POWER To for there success for EllecttionCOURU TP  Courotp  Goverment   Dectetor Of Admenistration The Will Accusse the Opponint  for Suucces. THEPhillippennes is very StronngEnfleuwenci a lCouroutp  DECTETOR The Phillippenness Goverment Is sourouded by  couroutp . COUROTPCouroutp Dectetor The Marcosese',
#       'textOriginal': 'THE PHILLIPPINNES Govermennt Is Sourounded be A couroutpDectetor Goverment  The Marcose GOVERMENTAdmenistration Will do there POWER To for there success for EllecttionCOURU TP  Courotp  Goverment   Dectetor Of Admenistration The Will Accusse the Opponint  for Suucces. THEPhillippennes is very StronngEnfleuwenci a lCouroutp  DECTETOR The Phillippenness Goverment Is sourouded by  couroutp . COUROTPCouroutp Dectetor The Marcosese',
#       'authorDisplayName': '@memercy7285',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k3AInWJTgtN0ykIqj_Jgu9DJBtIpIZ9dQsMUWjCg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@memercy7285',
#       'authorChannelId': {'value': 'UC9STCQGpRxS2N0LftR5hoOg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-05-10T04:23:27Z',
#       'updatedAt': '2025-05-10T04:23:27Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'lLLM8yPQaRUCr3pEyNeXnFHOjeE',
#    'id': 'UgxYx7nQ0mgEDsgslI54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'cAAnFwqxs3kvFhDxokMU2txMKw4',
#      'id': 'UgxYx7nQ0mgEDsgslI54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=xPb4FMfGbos&amp;t=287">4:47</a> I am Rodrigooo Roowaa Dutertee 😢',
#       'textOriginal': '4:47 I am Rodrigooo Roowaa Dutertee 😢',
#       'authorDisplayName': '@Du30yrs_inICC',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/5Tz5C0pTgmuUmo7INGznyQNeWZP3eZU3wnCtcF3PVLrT8Eq7aKO4Q1mrXNRaPHqQ6W5mZ-DUamM=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Du30yrs_inICC',
#       'authorChannelId': {'value': 'UCUdcwbY2tIrI4yKe8m8XssA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-05-08T02:36:24Z',
#       'updatedAt': '2025-05-08T02:36:24Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'USeiDwPSpXnpgz5kOeCO7jLklnU',
#    'id': 'UgyJwfrnF0S0TRSB6vN4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ArZOVQXe2VtTbJNLtim0ewN-SyU',
#      'id': 'UgyJwfrnF0S0TRSB6vN4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': '.,Hj. My., leve., Allan salinas Gatmaitan  apa apa DUC A.,  579 (01)(02)(142)',
#       'textOriginal': '.,Hj. My., leve., Allan salinas Gatmaitan  apa apa DUC A.,  579 (01)(02)(142)',
#       'authorDisplayName': '@Allangatmaitan-v7q',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzf_38osY0eh7aPQbfKu6wRof-DTAs7pSaNm9ZMqGPUJFfWyS5SFzzSHFBOz2qGsV8gw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Allangatmaitan-v7q',
#       'authorChannelId': {'value': 'UC11obwX1h6z5eJVNTVA1NBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-04-30T10:59:34Z',
#       'updatedAt': '2025-04-30T10:59:34Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'pHmj7oN36mBTmrgB8TtK6m8Dd4c',
#    'id': 'UgwIR827KzFmnlcmRL94AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xFz_dhtGE0dR4x4Z1L_rOHngaLg',
#      'id': 'UgwIR827KzFmnlcmRL94AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': '<a href="https://www.youtube.com/watch?v=xPb4FMfGbos&amp;t=285">4:45</a> I AM, RODRIGO, ROA, DUTERTE.',
#       'textOriginal': '4:45 I AM, RODRIGO, ROA, DUTERTE.',
#       'authorDisplayName': '@BulacanUMNChannel34',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/5HuakOI5dbAfzxaBsQPZD3PvTvdqdBYJb1Zvn70rcuJT24FpJOdoMejRT93L0GOF-EYRdTrzjys=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@BulacanUMNChannel34',
#       'authorChannelId': {'value': 'UCddklD9l74lo48---FBm6uQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-04-24T05:29:11Z',
#       'updatedAt': '2025-04-24T05:29:11Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'dNxgwVLS-Kd4_9h2kfyupKlNxis',
#    'id': 'UgwmCNJG2PHdKFVN6np4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'aI2XqOlsl0JpwuRbpWUT5fOVlVU',
#      'id': 'UgwmCNJG2PHdKFVN6np4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Tama lang na dito litisin si Digong. <br><br>Kung sa Pilipinas, yun mga sipsip sa kanya sa senado, kakastiguhin pa mga pulis na magsisilbi sa kanya ng warrant. Parang yun nangyari kay Quiboloy. San ka naman nakakita yun pugante pa kinampihan<br><br>Yun mga pamilya, delikado buhay nila sigurado. Hindi pa sila nakakarating ng RTC nabaril na sila ng riding in tandem. O kaya naman hinarass ng husto ng mga DDS<br><br>At ganun din mangyayari sa judge na hahawak ng kaso. Pagbabantaan buhay nya<br><br>Sabihin natin makulong si Digong. Ipapardon lang sya ng susunod na mananalong presidente lalo kung gusto ng boto from Mindanao',
#       'textOriginal': 'Tama lang na dito litisin si Digong. \n\nKung sa Pilipinas, yun mga sipsip sa kanya sa senado, kakastiguhin pa mga pulis na magsisilbi sa kanya ng warrant. Parang yun nangyari kay Quiboloy. San ka naman nakakita yun pugante pa kinampihan\n\nYun mga pamilya, delikado buhay nila sigurado. Hindi pa sila nakakarating ng RTC nabaril na sila ng riding in tandem. O kaya naman hinarass ng husto ng mga DDS\n\nAt ganun din mangyayari sa judge na hahawak ng kaso. Pagbabantaan buhay nya\n\nSabihin natin makulong si Digong. Ipapardon lang sya ng susunod na mananalong presidente lalo kung gusto ng boto from Mindanao',
#       'authorDisplayName': '@Ironheart73',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lI4e-1k4KexoUJjle-C17JegRr6__rl-9yEBXKanU=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Ironheart73',
#       'authorChannelId': {'value': 'UCMlZvjL7igKSEHMsRY2LeDA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2025-04-15T14:07:30Z',
#       'updatedAt': '2025-04-15T14:07:30Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'UJqUmOOD8GPhQXHWXTxomxcMgWc',
#    'id': 'UgxjM7mdbxcetq47ZHF4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YOKhctLNRBsHr3JqaISwE40Y9-8',
#      'id': 'UgxjM7mdbxcetq47ZHF4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Allan Salinas  Gatmaitan  DUC A.,  reportc Casi all albang ticnologi satalite network Telecom hotline.,  cumpany.,,, 24 company singk A.,  end tols  ., all Cesi.,  tou ICC',
#       'textOriginal': 'Allan Salinas  Gatmaitan  DUC A.,  reportc Casi all albang ticnologi satalite network Telecom hotline.,  cumpany.,,, 24 company singk A.,  end tols  ., all Cesi.,  tou ICC',
#       'authorDisplayName': '@Allangatmaitan-v7q',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nzf_38osY0eh7aPQbfKu6wRof-DTAs7pSaNm9ZMqGPUJFfWyS5SFzzSHFBOz2qGsV8gw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@Allangatmaitan-v7q',
#       'authorChannelId': {'value': 'UC11obwX1h6z5eJVNTVA1NBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-04-09T10:12:53Z',
#       'updatedAt': '2025-04-09T10:12:53Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '7dclqHyxDSXlzyq8L81JuFqQD1I',
#    'id': 'Ugz4ynEfKdS_Nifm56B4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'l0DiN4PlctrtzQAWpRPuT8BfKCA',
#      'id': 'Ugz4ynEfKdS_Nifm56B4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Neotahil',
#       'textOriginal': 'Neotahil',
#       'authorDisplayName': '@NeonitaHilo-c5c',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_kha02_9Ul-0i7-bVviA0vGlId-liZzPVQMGzeLqnUygpGthuE1DCRL-f9hmm6Y1aUYKw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@NeonitaHilo-c5c',
#       'authorChannelId': {'value': 'UCKPX2tFbD3XSjTusPrWyDTg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-04-08T17:34:10Z',
#       'updatedAt': '2025-04-08T17:34:10Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'zRddSPzijAnWdyF0eb7J5WKLd58',
#    'id': 'Ugz3qH-jQszDXCxrmGx4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'u7SlI_yw_zk_UHBgaWv4hT_Et9s',
#      'id': 'Ugz3qH-jQszDXCxrmGx4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Mga bais kayo',
#       'textOriginal': 'Mga bais kayo',
#       'authorDisplayName': '@JeraldVillaflor',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nbdc5AzjivOkOVFs1t3A1g2QWi7OLsMZHV2ihZTqZmqltNd7G5En2x7TJbw2Ac3mb2Bw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@JeraldVillaflor',
#       'authorChannelId': {'value': 'UCRFupR5cYxfUqPcvPBkD8Xg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-04-07T16:22:35Z',
#       'updatedAt': '2025-04-07T16:22:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'M7SqGnDb2jh4rQo2mjgPCId1tJA',
#    'id': 'UgwUgnGOzDyeTI-FhV54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'waAs8EnEUNgk0MhtOSRX1PjyAQU',
#      'id': 'UgwUgnGOzDyeTI-FhV54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'kanya kanyang iyak na ang mga bayarang DDShits! kalaboso na ang amo nila!',
#       'textOriginal': 'kanya kanyang iyak na ang mga bayarang DDShits! kalaboso na ang amo nila!',
#       'authorDisplayName': '@BarryAlcantara',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k78bXqxjvCHrukhuyGTsKlhlaQhxV6ae87tix931MAixZFqdBbIe8JVhOogv1wZNqh6A=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@BarryAlcantara',
#       'authorChannelId': {'value': 'UCAMlhIAbM3IZ1tIvyWBohZw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-04-03T23:05:05Z',
#       'updatedAt': '2025-04-03T23:05:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'LRAGAbBz3K0LkIhdDNXe4IVuK3Q',
#    'id': 'Ugzn22leSwWy1edPNLl4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ybr0gSGhfk4Sp9JYNrLzSYwnrtc',
#      'id': 'Ugzn22leSwWy1edPNLl4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'tama lang na makulong na yang si digongnyo! sana ay makulong din ang mga alagad nya para naman magkaron na ng hustisya ang mga kawawang biktima!',
#       'textOriginal': 'tama lang na makulong na yang si digongnyo! sana ay makulong din ang mga alagad nya para naman magkaron na ng hustisya ang mga kawawang biktima!',
#       'authorDisplayName': '@MeganLopez-j8t',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m5DHdJOQs40hzoitGNZg5x-fmV6OYmJoszNAslGR0idT_rVnRjRUDprHsTC8XFm7CrIA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MeganLopez-j8t',
#       'authorChannelId': {'value': 'UClPybLAU0eUEHKXvz2eYkdg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-04-03T22:47:05Z',
#       'updatedAt': '2025-04-03T22:47:05Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'aUwryxCQVoPWhQgJYcwaZi-Msig',
#    'id': 'UgxAN-E2A0B7YNbbIrN4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eDK7WeKyfcu9qiv6pIk-1YJnt4A',
#      'id': 'UgxAN-E2A0B7YNbbIrN4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'hindi na umubra ang mga pambubudol ng mga dutertards! himas rehas na kayo!',
#       'textOriginal': 'hindi na umubra ang mga pambubudol ng mga dutertards! himas rehas na kayo!',
#       'authorDisplayName': '@MiriamLlaneta',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lCcLaQxWcvI2EGO1Yx8JghVogwuIvweQtKO2WljVQO8Z9U-9WIqXep9b4I_4RwnbLfMQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@MiriamLlaneta',
#       'authorChannelId': {'value': 'UCcRV0-fgdnj5WKgIIYmPm7A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-04-03T22:34:06Z',
#       'updatedAt': '2025-04-03T22:34:06Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '4YCncKk2PKi77-J4oW_ftnYTQtc',
#    'id': 'UgxhO4S7R-WoTAjbkS54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ltLx4rglvdsRbos9m9k3Qa8-lX8',
#      'id': 'UgxhO4S7R-WoTAjbkS54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Magaling mg drama c digong',
#       'textOriginal': 'Magaling mg drama c digong',
#       'authorDisplayName': '@user-fc2ls9dy4k',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lglEVmFFvJcGTthjC40ZSDKFEIq_FMcZCu6WFK9q2d4jH4JFUcHxRkgfTb41TbZjELqg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-fc2ls9dy4k',
#       'authorChannelId': {'value': 'UCaC53JVx4KAtSOjdInKavbA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-31T11:02:13Z',
#       'updatedAt': '2025-03-31T11:02:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ws0MQvuZlfgA3_UZM1SF4Nd36jM',
#    'id': 'Ugy57H7l0FuvZG-d3mN4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'HiL-G1bV1ZHdkeW1j93WSRxNopQ',
#      'id': 'Ugy57H7l0FuvZG-d3mN4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'The west is ashamed of the world moving away from Europe and now they are using all they can to keep the grip Europe is the past',
#       'textOriginal': 'The west is ashamed of the world moving away from Europe and now they are using all they can to keep the grip Europe is the past',
#       'authorDisplayName': '@walkalone702',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/m0YG3NQZibZyqNAkiHW2YySOMW7K5q9vvdrTQQ1g5BPmuCW7bpz7hXHn-M1FCZr8qXw8SQoBJQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@walkalone702',
#       'authorChannelId': {'value': 'UC6pAES3A8G6rqBubMDl4KRQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-31T09:29:31Z',
#       'updatedAt': '2025-03-31T09:29:31Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '0FCXtLQ0dsjYkAOGn5svuPYeb7U',
#    'id': 'UgxiSi9sa-Xg07CQNYV4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'OXxM3gYd7yiPVcltIEUo4bdhDYs',
#      'id': 'UgxiSi9sa-Xg07CQNYV4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Best actor, duterte, hahahahahahahahaha',
#       'textOriginal': 'Best actor, duterte, hahahahahahahahaha',
#       'authorDisplayName': '@LeviStark-dv2el',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_la-H9d58afKmA1gx1QVtyU-KPQL-P_-zFly6BX3pJlvct2ymNDOK1_281YXJGJXUfWug=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@LeviStark-dv2el',
#       'authorChannelId': {'value': 'UC05JLU4MYxKxwRqaY2m5yrw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 2,
#       'publishedAt': '2025-03-29T03:41:12Z',
#       'updatedAt': '2025-03-29T03:41:12Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RcVMTM83JBfRR_aJmHsJOTk6vqU',
#    'id': 'UgwMV1imR_sBtAcaF-54AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'UpjUEc5qSgfyMaeE1F0OD7HdFQU',
#      'id': 'UgwMV1imR_sBtAcaF-54AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'WE LOVE YOU MR. DUTERTE 🔥🔥🔥🔥🔥',
#       'textOriginal': 'WE LOVE YOU MR. DUTERTE 🔥🔥🔥🔥🔥',
#       'authorDisplayName': '@YujinVerdy',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/UxRWDjraXRo0h7nESzbbLBEjAr6dBlSZMXle-0_NF7sx2IhTWRMBUFUCXZMLqWAjVzELAosw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@YujinVerdy',
#       'authorChannelId': {'value': 'UCZZXoUUOyODW64Zb6VmVxYQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-26T15:53:33Z',
#       'updatedAt': '2025-03-26T15:53:33Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Ulk3H4o0N9tEdZqKL9GTLFEUEbg',
#    'id': 'UgyRHEzH7Z7vvG6WgOV4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'AedujYJpRW-zXyvH3FUsc8L9FFU',
#      'id': 'UgyRHEzH7Z7vvG6WgOV4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'nakakaiyak, kitang nahihirapan  sya ... Marcos BBM manangot ka sa ginawa sa tunay na AMA ng bayan.',
#       'textOriginal': 'nakakaiyak, kitang nahihirapan  sya ... Marcos BBM manangot ka sa ginawa sa tunay na AMA ng bayan.',
#       'authorDisplayName': '@joskolord',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/OCnbWgbM6ydYhZ6sBy25Ffc8gwEmeYK5VBiGjmSX1VPfqm3DYQIC2t2zBE4NKKSUCfNsQIfdPw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@joskolord',
#       'authorChannelId': {'value': 'UC6Kdvl3V_4n-RyqI36J_reg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-26T14:07:41Z',
#       'updatedAt': '2025-03-26T14:07:41Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'O6ty3FfnFJbW0R1hU7alZJFabqQ',
#    'id': 'UgwPic93VJlKLEUkicF4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'tJe67T3MXTp2FtP2OFbiCNODoKQ',
#      'id': 'UgwPic93VJlKLEUkicF4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'At the very least, the ICC should have representatives from all over the world to hold trials in their court; only then can it be considered fair. It&#39;s called &quot;international,&quot; but everyone in the court has white hair. That&#39;s why Netanyahu hasn&#39;t been arrested—because his hair is white, just like Biden&#39;s.',
#       'textOriginal': 'At the very least, the ICC should have representatives from all over the world to hold trials in their court; only then can it be considered fair. It\'s called "international," but everyone in the court has white hair. That\'s why Netanyahu hasn\'t been arrested—because his hair is white, just like Biden\'s.',
#       'authorDisplayName': '@comp__bot__trojan7119',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/v6ezU9_RESzm4B_G9XG7QjK5oZFvIweLwpV24hwhTX_FMgVnl1YFmP1OJSTl8-C_bnuZkAF6Lpo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@comp__bot__trojan7119',
#       'authorChannelId': {'value': 'UCRHvU7CGT4whyo0-bPElGDw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-26T04:33:56Z',
#       'updatedAt': '2025-03-26T04:33:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_ZGktqt65u6xsnnGa6Oz8i1K-RA',
#    'id': 'UgxwyqwS9_Mx3M5Zm814AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'W3g956WnYO_UbgeYTHONt3ucgy4',
#      'id': 'UgxwyqwS9_Mx3M5Zm814AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': '😂😂 nabulol na ung maton dati haha 😂',
#       'textOriginal': '😂😂 nabulol na ung maton dati haha 😂',
#       'authorDisplayName': '@JhezkerMontero-b2h',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mXl5vEZetSFCfuG2B7_VLqc38fE5TVJMtL_CGIeMUbdXJf55quvy5KONcX81xCv66Llw=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@JhezkerMontero-b2h',
#       'authorChannelId': {'value': 'UCVeFXNFvPCfye6l5my01T5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-25T14:04:57Z',
#       'updatedAt': '2025-03-25T14:04:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'wbOrCxyNKkGYIsmPs8iFU8zHPCk',
#    'id': 'UgwrUASA4nxU7Z_bvQ14AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'JybATPDtrmG5guduBhAxQRsyByg',
#      'id': 'UgwrUASA4nxU7Z_bvQ14AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'nakakalungkot ung sitwasyon ni FPRRD natin 😥',
#       'textOriginal': 'nakakalungkot ung sitwasyon ni FPRRD natin 😥',
#       'authorDisplayName': '@riaescarez-we6bz',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/6ZuoVN6xxjpufSXmjo9zK5Vsc7ChixTi6l3iQPYMnwxflMtbBASZv9CZK7HTGRuvxQoAfSDJ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@riaescarez-we6bz',
#       'authorChannelId': {'value': 'UChXQLQzprzrpiQlD0IdUFnw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-25T06:13:13Z',
#       'updatedAt': '2025-03-25T06:13:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'whPStJbigcizLezYWbcxhdzAOws',
#    'id': 'UgwOMc5zp4pWIacIqpB4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '5gx1pxnuLKBD8Kmn2XPCGnleL-A',
#      'id': 'UgwOMc5zp4pWIacIqpB4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Naaawa ako right now kay duterte kasi matanda na sxa pero to think what happened those times na malakas pa sxa, daming nangyare, subrang tapang at kaya niyang  pumatay nang tao with his dds. yung panahon nang administration niya walang makapalag kasi patay pag papalag ka. kaya yung awa ko if going back to what happened back then subrang daming namatay under his leadership, is being replaced by his deserve it.',
#       'textOriginal': 'Naaawa ako right now kay duterte kasi matanda na sxa pero to think what happened those times na malakas pa sxa, daming nangyare, subrang tapang at kaya niyang  pumatay nang tao with his dds. yung panahon nang administration niya walang makapalag kasi patay pag papalag ka. kaya yung awa ko if going back to what happened back then subrang daming namatay under his leadership, is being replaced by his deserve it.',
#       'authorDisplayName': '@ate_g12',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/FxpBFCD7CX1pn3rdqGiOOrcI5TS9t72atCHdJZtTGjh-45pmKaGCQuTozI0eRLHB4J0hLFezQA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ate_g12',
#       'authorChannelId': {'value': 'UCc9pUXL9gaiGiIEbbHnsx5g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-24T03:51:21Z',
#       'updatedAt': '2025-03-24T03:52:58Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'qHcSC3JpakDS0e5nAdQpZZXcuxU',
#    'id': 'Ugxyp00V4LTCBaCHWK94AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1YP8P-p1PLlXwhMzqtSsN7EIqQg',
#      'id': 'Ugxyp00V4LTCBaCHWK94AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'BHiL9IF-hoaxjO4OIr3AJv33x8g',
#      'id': 'UgxteVxveYaAKz9S91N4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'May nagawang mali man...Tama lang yon para sa mga nagawa nilang kasalanan... justice for tatay digong',
#       'textOriginal': 'May nagawang mali man...Tama lang yon para sa mga nagawa nilang kasalanan... justice for tatay digong',
#       'authorDisplayName': '@mioski10',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/gccrxlGJNf2jnAVezve5ca0LB3PNIqQVdZxb3jQPzCi-YaQncVMzbvzYjBZUerwIBrz_fVWAKg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@mioski10',
#       'authorChannelId': {'value': 'UCVwcv_e6pe8jfsAS1QKdsBA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-23T15:25:54Z',
#       'updatedAt': '2025-03-23T15:25:54Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '2oqgrQq6qneDquuRxpLOMFPInwU',
#    'id': 'UgyR8PnbIf63smy4VTp4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'aCGWczJ_a7aEy5vtmJAtXiiR7Ao',
#      'id': 'UgyR8PnbIf63smy4VTp4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Where Is ICC during Palistine Genocide????',
#       'textOriginal': 'Where Is ICC during Palistine Genocide????',
#       'authorDisplayName': '@abdulhalilabdulhamid7579',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lqULl_zl4kd2Kqu-NGfQAeRgktPwzB-Z0A1Snc5T96-MRs7PMnyyGHCmsAyOOuHNpt5Q=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@abdulhalilabdulhamid7579',
#       'authorChannelId': {'value': 'UCQ7TA-ntJbQEfclCJk0M14w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-23T14:26:03Z',
#       'updatedAt': '2025-03-23T14:26:03Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'Di4xTg_MWnD-184YI78BEwI8EQs',
#    'id': 'UgycIn3AblpyBrAx7gJ4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '7EFMuLYmylyl9EBx4u2DbKSqzjA',
#      'id': 'UgycIn3AblpyBrAx7gJ4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Akala ko ba sisipain mo ang ICC Digz bakit parang takot na takot ang boses mo?',
#       'textOriginal': 'Akala ko ba sisipain mo ang ICC Digz bakit parang takot na takot ang boses mo?',
#       'authorDisplayName': '@alexgaringalao4915',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k2dzioBeuC0nPYnwndXMEIXFXNVJJYq75nwfolvCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@alexgaringalao4915',
#       'authorChannelId': {'value': 'UCQY8ZVUOEqNyaasG0DHWVnQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-23T09:46:49Z',
#       'updatedAt': '2025-03-23T09:46:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nojgBt8OHu1fRRVVd00jeAXTVdE',
#    'id': 'UgwfPoLt0QmVK0RyNXZ4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '2eOxwkPt8octh1c7F0lrYkqvFoI',
#      'id': 'UgwfPoLt0QmVK0RyNXZ4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'HOY  de gong gong NAKAKAHIYA  KA KALA NG  MGA TAONG NAGOYO MO &gt; MATAPANG KA &gt; KALA NILA TALAGANG MANANAMPAL KA  NGAYON NAG-SA-SAKIT SAKIT KA PA- &gt; PAAWA DRAMA ? BAKIT GANYAN ANG BOSES MO NALO-LON MO BA ANG BAYAG MO? MAG-PAKALALAKI KA NAMAN KAHIT NA WAL KANG BAYAG!',
#       'textOriginal': 'HOY  de gong gong NAKAKAHIYA  KA KALA NG  MGA TAONG NAGOYO MO > MATAPANG KA > KALA NILA TALAGANG MANANAMPAL KA  NGAYON NAG-SA-SAKIT SAKIT KA PA- > PAAWA DRAMA ? BAKIT GANYAN ANG BOSES MO NALO-LON MO BA ANG BAYAG MO? MAG-PAKALALAKI KA NAMAN KAHIT NA WAL KANG BAYAG!',
#       'authorDisplayName': '@tmn-galentong2545',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_k_nRiV9fKWbUy9Yr7JSk-tO5NZEAnL76ZXhOOvKA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@tmn-galentong2545',
#       'authorChannelId': {'value': 'UCVowUjEzL9oCEdzh_35-cTQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-22T23:49:20Z',
#       'updatedAt': '2025-03-22T23:49:20Z'}},
#     'canReply': True,
# ...
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-22T03:07:35Z',
#       'updatedAt': '2025-03-22T03:07:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gVWcT7Y4EtiUY1-Vkq5RbFADkIw',
#    'id': 'UgyGTcSyt76I3g0gPix4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '0iRtfcCj9S1IvStDDSjJMtQ8KvU',
#      'id': 'UgyGTcSyt76I3g0gPix4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'JUST GIVE DIGONYO AN INTERIM RELEASE AND IT IS SIMILAR TO OPENING A PANDORA&#39;S BOX.',
#       'textOriginal': "JUST GIVE DIGONYO AN INTERIM RELEASE AND IT IS SIMILAR TO OPENING A PANDORA'S BOX.",
#       'authorDisplayName': '@edgarcordova8730',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lXCpv9R4B07OCtxS5nKbqTd2dOphEMw5_JbLklUmIjhy4uMx4EL0dgbCbWmLeygOLbOQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@edgarcordova8730',
#       'authorChannelId': {'value': 'UCH1IIQ0c7YAMiItvSSBfwxw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-22T03:01:56Z',
#       'updatedAt': '2025-03-22T03:01:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'dQbeZCuyMkW8zx2nt-C1ufL0ZmU',
#       'id': 'UgyGTcSyt76I3g0gPix4AaABAg.AFxahb4oBGUAFxb75YrXG3',
#       'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#        'videoId': 'xPb4FMfGbos',
#        'textDisplay': 'Interim release has never been granted by the ICC to suspects being charged with crimes against humanity.',
#        'textOriginal': 'Interim release has never been granted by the ICC to suspects being charged with crimes against humanity.',
#        'parentId': 'UgyGTcSyt76I3g0gPix4AaABAg',
#        'authorDisplayName': '@MrSlanderer',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/kO8Pphv0Pl1YEHTTuls8shJaIfrsAmP47AZRVF_e_C43KqyMsjaYepVCwIo-BMh2yZlmTBP9Dw=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@MrSlanderer',
#        'authorChannelId': {'value': 'UCcmdXAMveg0Y0_4Or2yfe5w'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2025-03-22T03:05:33Z',
#        'updatedAt': '2025-03-22T03:05:33Z'}}]}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'xciG7VSVno1pdhA3rgeiD_UTXI8',
#    'id': 'UgwhbqdKsfFW5aBcuRR4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'YfCNXL-SuAts3IpZGwGhOqhlf-c',
#      'id': 'UgwhbqdKsfFW5aBcuRR4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'dito natin nalaman mga killings na nangyare ng nakaraan under sa kanyang panunungkulan..ang dami pala😮 bukod pa itong tokhang issue..sa laki at dami ng killing involved guilty ang dulo nito.',
#       'textOriginal': 'dito natin nalaman mga killings na nangyare ng nakaraan under sa kanyang panunungkulan..ang dami pala😮 bukod pa itong tokhang issue..sa laki at dami ng killing involved guilty ang dulo nito.',
#       'authorDisplayName': '@angelitopabustan4554',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mClrnOJ8e0GHND7cVpVH8zukhQH1ajYX-vTR36jdMwWA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@angelitopabustan4554',
#       'authorChannelId': {'value': 'UC9Wms18FoTVtMQEZ72R8ctQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-22T01:18:59Z',
#       'updatedAt': '2025-03-22T01:18:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nWYiIZ6VBRhXO06g6nmILsSKdls',
#    'id': 'UgyUiDKpSQUezghaa_x4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'EBpldnhaHHgcX7uNVMuQVStT_XY',
#      'id': 'UgyUiDKpSQUezghaa_x4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Wala siyang kasal anan mabait siya dati naming president yan,',
#       'textOriginal': 'Wala siyang kasal anan mabait siya dati naming president yan,',
#       'authorDisplayName': '@EdnaAlbia',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n_lui30_R4aFboFtgT_VxYjD4iTGYWon2fteKOKgKDhtSlE3mEcaX1nF_zJZGiJY87Og=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@EdnaAlbia',
#       'authorChannelId': {'value': 'UC0XR4_KMGPfdflCQLnjRIow'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-22T00:45:49Z',
#       'updatedAt': '2025-03-22T00:45:49Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'RlHdDCoGNF2jOCcFHoe-7WH31r4',
#    'id': 'Ugw7LmBIyxcm26gr7Ft4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': '1e3EUxun8rFVDGbi7gQMNVyn7ck',
#      'id': 'Ugw7LmBIyxcm26gr7Ft4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'pede po pala yan sa ibang bansa lilitisin ang di nila kalahi...😅',
#       'textOriginal': 'pede po pala yan sa ibang bansa lilitisin ang di nila kalahi...😅',
#       'authorDisplayName': '@OhllyAyson',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mtw9dXj-Y_Wyijj6uKcJvVqQK4G2XnYJcLMHTa2GyZyI6fmOksfSMpEJve-hbGv0GeTg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@OhllyAyson',
#       'authorChannelId': {'value': 'UCMzjRROBeOPnTwZFDIK8N9g'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T23:28:16Z',
#       'updatedAt': '2025-03-21T23:28:16Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OG7ayVYvGoilzV1HQcq9l2sr6pc',
#    'id': 'UgzI3GkgGEHhAIdcs294AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'a8uAqdA1TQJmIz1fUhBcroFyqB8',
#      'id': 'UgzI3GkgGEHhAIdcs294AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'This man was elected for the clean up of the Philippines and now this 😮, not right .',
#       'textOriginal': 'This man was elected for the clean up of the Philippines and now this 😮, not right .',
#       'authorDisplayName': '@aliveandfilming2',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/xLCcAd7__Ps5YEnc5puwzxenahjctNOERQ6sk-I0VwV-WbjVlhhc7N7dAau_23yiifqkUfa-KA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@aliveandfilming2',
#       'authorChannelId': {'value': 'UCJSfSDz66Knv0ri0Y-2ufTA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T21:37:56Z',
#       'updatedAt': '2025-03-21T21:37:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'KA4fkGfD-Uny4ZjRZqL5Qzcbgqk',
#    'id': 'UgxrgJpu6W3HLMmDnKN4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'QYS5KyksTbUPBvIIdP94BNOkxa0',
#      'id': 'UgxrgJpu6W3HLMmDnKN4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Di pwede ang delay tatctics nyo dyan tulad ginawa ni zara  sa congress 🙄',
#       'textOriginal': 'Di pwede ang delay tatctics nyo dyan tulad ginawa ni zara  sa congress 🙄',
#       'authorDisplayName': '@ENSavedbygrace_Channel',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/QqzlNKQXho8kcFoZ8eHPdx8W2IUyuRFFzY-OE-vcCEbnFgqEyc8deuMnYhGZHK6eBjeiR4H5Ew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ENSavedbygrace_Channel',
#       'authorChannelId': {'value': 'UC1w1Ig8AKoVOsN48Znrg7AA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2025-03-21T13:24:39Z',
#       'updatedAt': '2025-03-21T13:24:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'AGGbsafPbcMnOaVWOL_ihy8wWeA',
#    'id': 'UgxAGhl7upsNdCAqHGB4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'XvgToqaUSBuyZbjZPFZUdTTVaGY',
#      'id': 'UgxAGhl7upsNdCAqHGB4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Sya nga inaresto yung ginawaan nya pinatay na agad buti nga sya nililitis pa yung victim nya na aganas na kawawa sya kasi maganda na sya kaso sino ba ang mas kawawa at hindi nabigyan ng due process',
#       'textOriginal': 'Sya nga inaresto yung ginawaan nya pinatay na agad buti nga sya nililitis pa yung victim nya na aganas na kawawa sya kasi maganda na sya kaso sino ba ang mas kawawa at hindi nabigyan ng due process',
#       'authorDisplayName': '@ENSavedbygrace_Channel',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/QqzlNKQXho8kcFoZ8eHPdx8W2IUyuRFFzY-OE-vcCEbnFgqEyc8deuMnYhGZHK6eBjeiR4H5Ew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ENSavedbygrace_Channel',
#       'authorChannelId': {'value': 'UC1w1Ig8AKoVOsN48Znrg7AA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T13:19:40Z',
#       'updatedAt': '2025-03-21T13:19:40Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5v8W6e3N0mrqsoaLiYwA5MuSXok',
#    'id': 'UgyKJ86PDeECiw076i14AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'PZ-ws7-rhcLuMeQkltdgxxb-4No',
#      'id': 'UgyKJ86PDeECiw076i14AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Sa airplain palang me medical asssis na po ah',
#       'textOriginal': 'Sa airplain palang me medical asssis na po ah',
#       'authorDisplayName': '@ENSavedbygrace_Channel',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/QqzlNKQXho8kcFoZ8eHPdx8W2IUyuRFFzY-OE-vcCEbnFgqEyc8deuMnYhGZHK6eBjeiR4H5Ew=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@ENSavedbygrace_Channel',
#       'authorChannelId': {'value': 'UC1w1Ig8AKoVOsN48Znrg7AA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T13:18:13Z',
#       'updatedAt': '2025-03-21T13:18:13Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '5wn6QnURTuttKI3TONJIdC-rr3M',
#    'id': 'UgxvkUI0PyjSbOV_4AN4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'xrxhtFc7fNDQwFPT_iRzO0mhLxU',
#      'id': 'UgxvkUI0PyjSbOV_4AN4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'The Philippines is ridiculous. To voluntarily send their former president to the International Court of Justice for trial! Isn&#39;t the Philippines a sovereign and independent country? It&#39;s so embarrassing.',
#       'textOriginal': "The Philippines is ridiculous. To voluntarily send their former president to the International Court of Justice for trial! Isn't the Philippines a sovereign and independent country? It's so embarrassing.",
#       'authorDisplayName': '@gegedongfang',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/PaG0AwSA_PC8-IqlX-UBfUHwOwNHQsT5eZFVXR_jyW9YJ5xbQ0njYGFcZ2FhAcU93aQS4Kin=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@gegedongfang',
#       'authorChannelId': {'value': 'UC1LZJ0o9A8BYVxi5faKLsQQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T11:11:32Z',
#       'updatedAt': '2025-03-21T11:11:32Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'nRb20VJfsT8lLt6OysCGr-vUlF0',
#    'id': 'UgzEdtXG7-BheRo3KZt4AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'NwKM8bq4xOLT9vjkcx2WZO3JG1I',
#      'id': 'UgzEdtXG7-BheRo3KZt4AaABAg',
#      'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#       'videoId': 'xPb4FMfGbos',
#       'textDisplay': 'Klasing imternational atty. yan di marunong mag english',
#       'textOriginal': 'Klasing imternational atty. yan di marunong mag english',
#       'authorDisplayName': '@victorinojuancitojr.5576',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nVG5trOBub4FKPni5L533YgZHYBbGnjGf7-xoZ9fbfflfgx4NrlPNIxNgu90DRzF6btQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@victorinojuancitojr.5576',
#       'authorChannelId': {'value': 'UCK0F3AcdtV3xpYfJpWvDKiA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2025-03-21T10:07:04Z',
#       'updatedAt': '2025-03-21T10:07:04Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True},
#    'replies': {'comments': [{'kind': 'youtube#comment',
#       'etag': 'Ml85b9wFqvfxrSkmHCyOmpA-9FI',
#       'id': 'UgzEdtXG7-BheRo3KZt4AaABAg.AFvmZZUVmmCAFvqvQY67ej',
#       'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#        'videoId': 'xPb4FMfGbos',
#        'textDisplay': 'kaya nga international Court. hindi ito american court',
#        'textOriginal': 'kaya nga international Court. hindi ito american court',
#        'parentId': 'UgzEdtXG7-BheRo3KZt4AaABAg',
#        'authorDisplayName': '@GeraldMunar',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n_Qj2BiObh7k6oDshLdUbv-M1mqkvQAhtNZasFH2HCUEg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@GeraldMunar',
#        'authorChannelId': {'value': 'UC-YSZAv_6ns7o-tqw19Tzxg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 1,
#        'publishedAt': '2025-03-21T10:45:08Z',
#        'updatedAt': '2025-03-21T10:45:08Z'}},
#      {'kind': 'youtube#comment',
#       'etag': 'Ew3jIY8B2wN892L5HoqnEEFAoZE',
#       'id': 'UgzEdtXG7-BheRo3KZt4AaABAg.AFvmZZUVmmCAFvr1qSDrZd',
#       'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#        'videoId': 'xPb4FMfGbos',
#        'textDisplay': 'hindi sinasamba ng ibang european contry ang english language. same sa Japan',
#        'textOriginal': 'hindi sinasamba ng ibang european contry ang english language. same sa Japan',
#        'parentId': 'UgzEdtXG7-BheRo3KZt4AaABAg',
#        'authorDisplayName': '@GeraldMunar',
#        'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_n_Qj2BiObh7k6oDshLdUbv-M1mqkvQAhtNZasFH2HCUEg=s48-c-k-c0x00ffffff-no-rj',
#        'authorChannelUrl': 'http://www.youtube.com/@GeraldMunar',
#        'authorChannelId': {'value': 'UC-YSZAv_6ns7o-tqw19Tzxg'},
#        'canRate': True,
#        'viewerRating': 'none',
#        'likeCount': 0,
#        'publishedAt': '2025-03-21T10:46:09Z',
#        'updatedAt': '2025-03-21T10:46:09Z'}}]}}]}

# %% [markdown]
# We can see that the contents are quite long, but if we take the time to analyze it, we'll realize it's really just a nested dictionary with the following keys: `kind`, `etag`, `nextPageToken`, `pageInfo`, and `items`.
#
# The values in `pageInfo` tell us how many results are included in this set--in this case, 50 comments and their corresponding replies. The 50 comments are contained as dictionaries within the `items` key.
#
# To confirm, let's check the length of the `items`.

# %%
len(video_response['items'])
# Out:
# 50

# %% [markdown]
# ## Inspecting a single YouTube comment

# %% [markdown]
# Now, let's try and see what each item in the response looks like. Let's examine the 1st item in the list.

# %%
video_response['items'][0]
# Out:
# {'kind': 'youtube#commentThread',
#  'etag': '3QTe6t3GBHw3uoh678KrcC8yCeg',
#  'id': 'UgxKqA6e6cbuxrTcN854AaABAg',
#  'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#   'videoId': 'xPb4FMfGbos',
#   'topLevelComment': {'kind': 'youtube#comment',
#    'etag': 'yb-SxNKCYpBxFlt_X-QqnEYh2As',
#    'id': 'UgxKqA6e6cbuxrTcN854AaABAg',
#    'snippet': {'channelId': 'UCE2606prvXQc_noEqKxVJXA',
#     'videoId': 'xPb4FMfGbos',
#     'textDisplay': 'Sept 23, 2026',
#     'textOriginal': 'Sept 23, 2026',
#     'authorDisplayName': '@farinyeshar.697',
#     'authorProfileImageUrl': 'https://yt3.ggpht.com/Ga_lioy2Mz_mMDHcIwTOqgyFKysK2XbBSWbv39XxvbyvN1d69qoEKGLEmKZT4kRvldaRwMy8EQ=s48-c-k-c0x00ffffff-no-rj',
#     'authorChannelUrl': 'http://www.youtube.com/@farinyeshar.697',
#     'authorChannelId': {'value': 'UCYR1Gq2JNC9w_ur6ChxOJAg'},
#     'canRate': True,
#     'viewerRating': 'none',
#     'likeCount': 0,
#     'publishedAt': '2025-08-07T14:01:01Z',
#     'updatedAt': '2025-08-07T14:01:01Z'}},
#   'canReply': True,
#   'totalReplyCount': 0,
#   'isPublic': True}}

# %% [markdown]
# We can extract the following
# - textDisplay
# - id
# - publishedAt
# - textOriginal
#
# Then add additional features
# - likeCount
# - repliedParentId

# %%
# For the original comment
print(
  f'https://www.youtube.com/watch?v={video_id}&lc={video_response["items"][0]["snippet"]["topLevelComment"]["id"]}'
)
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['publishedAt'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['textOriginal'])
print(video_response['items'][0]['snippet']['topLevelComment']['snippet']['likeCount'])
# No repliedParentId
# Out:
# https://www.youtube.com/watch?v=xPb4FMfGbos&lc=UgxKqA6e6cbuxrTcN854AaABAg
# Sept 23, 2026
# 2025-08-07T14:01:01Z
# Sept 23, 2026
# 0

# %% [markdown]
# ## Extracting replies from comment

# %% [markdown]
# If `totalReplyCount` is greater than 0, we can extract the replies to the comment.
# In the `video_response` object, we can see that the replies are nested within the `comments` key. HOWEVER, this method does not include all replies.
#
# As such, we have to use the `comments.list` method to get all replies to a comment.
# Refer to [CommentsList](https://developers.google.com/youtube/v3/docs/comments/list) document for more information.

# %%
video_response['items'][-1]['snippet']['totalReplyCount']
# Out:
# 2

# %%
len(
  video_response['items'][-1]['replies']['comments']
)
# Out:
# 2

# %% [markdown]
# Using a similar process, we can also extract the one reply to this comment. We know there's three replies because of the value of the `totalReplyCount` key.

# %%
comment_number = -1
total_reply_count = video_response['items'][comment_number]['snippet']['totalReplyCount']

if total_reply_count > 0:
  parent_id = video_response['items'][comment_number]['snippet']['topLevelComment']['id']

  replies = youtube.comments().list(
    part='snippet', parentId=parent_id, maxResults=50
  ).execute()

  for reply in replies['items']:
    print(
      f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}"
    )
    print(reply['snippet']['textDisplay'])
    print(reply['snippet']['publishedAt'])
    print(reply['snippet']['textOriginal'])
    print(reply['snippet']['likeCount'])
    print(reply['snippet']['parentId'])
    print()
# Out:
# https://www.youtube.com/watch?v=xPb4FMfGbos&lc=UgzEdtXG7-BheRo3KZt4AaABAg.AFvmZZUVmmCAFvqvQY67ej
# kaya nga international Court. hindi ito american court
# 2025-03-21T10:45:08Z
# kaya nga international Court. hindi ito american court
# 1
# UgzEdtXG7-BheRo3KZt4AaABAg
#
# https://www.youtube.com/watch?v=xPb4FMfGbos&lc=UgzEdtXG7-BheRo3KZt4AaABAg.AFvmZZUVmmCAFvr1qSDrZd
# hindi sinasamba ng ibang european contry ang english language. same sa Japan
# 2025-03-21T10:46:09Z
# hindi sinasamba ng ibang european contry ang english language. same sa Japan
# 0
# UgzEdtXG7-BheRo3KZt4AaABAg

# %% [markdown]
# ## Automating the extraction

# %% [markdown]
# Now that we know how to extract individual comments from YouTube videos, we need to figure out how we can automate this process so that we can build a corpus of comments without manually getting comments and replies one by one.
#
# To do this, we rely on the following:
# 1.   the consistency of the nested dictionary results structure of the YouTube API
# 2.   Python loops
# 3.   page tokens
#
# Let's work on the first two.

# %% [markdown]
# First, we create a list where we will store all scraped data.

# %%
comments = []

# %% [markdown]
# Then, we use loops to iterate through the contents of `video_response`.

# %%
video_id = 'xPb4FMfGbos'

# iterate through items
for item in video_response['items']:

  # extract comment from each item
  comment = item['snippet']['topLevelComment']['snippet']

  # append comment to list of comments
  comments.append([
    comment['textDisplay'],
    f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
    comment['publishedAt'],
    comment['textOriginal'],
    comment['likeCount'],
    np.nan
  ])

  # count number of replies
  total_reply_count = item['snippet']['totalReplyCount']

  # if there is at least one reply
  if total_reply_count > 0:
    parent_id = item["snippet"]["topLevelComment"]["id"]

    replies = youtube.comments().list(
      part='snippet', parentId=parent_id, maxResults=50
    ).execute()

    # iterate through the replies
    for reply in replies['items']:
      # extract text from each reply
      # append reply to list of comments
      replyBody = reply['snippet']
      comments.append([
        replyBody['textDisplay'],
        f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
        replyBody['publishedAt'],
        replyBody['textOriginal'],
        replyBody['likeCount'],
        replyBody['parentId']
      ])

# %%
youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                 title  \
# 0                                       Sept 23, 2026
# 1   When Digong said to the Police who carried his...
# 2   ang tapang nuong hindi pa naaresto..dalian daw...
# 3   Life in prison please. <a href="UCkszU2WH9gy1m...
# 4                          Galing mag drama ni digong
# 5         Pilipino ako duterti ako si allan gaTmaitan
# 6   Ply gus wag yong kame ioababoy duterti melmnid...
# 7   I think this ICC thing looks inaccurate, becau...
# 8   For a french judge, that judge hair is a bit u...
# 9   THE PHILLIPPINNES Govermennt Is Sourounded be ...
# 10  <a href="https://www.youtube.com/watch?v=xPb4F...
# 11  .,Hj. My., leve., Allan salinas Gatmaitan  apa...
# 12  <a href="https://www.youtube.com/watch?v=xPb4F...
# 13  Tama lang na dito litisin si Digong. <br><br>K...
# 14  Allan Salinas  Gatmaitan  DUC A.,  reportc Cas...
# 15                                           Neotahil
# 16                                      Mga bais kayo
# 17  kanya kanyang iyak na ang mga bayarang DDShits...
# 18  tama lang na makulong na yang si digongnyo! sa...
# 19  hindi na umubra ang mga pambubudol ng mga dute...
# 20                         Magaling mg drama c digong
# 21  The west is ashamed of the world moving away f...
# 22            Best actor, duterte, hahahahahahahahaha
# 23                      WE LOVE YOU MR. DUTERTE 🔥🔥🔥🔥🔥
# 24  nakakaiyak, kitang nahihirapan  sya ... Marcos...
# 25  At the very least, the ICC should have represe...
# 26                😂😂 nabulol na ung maton dati haha 😂
# 27       nakakalungkot ung sitwasyon ni FPRRD natin 😥
# 28  Naaawa ako right now kay duterte kasi matanda ...
# 29  Mercy boucoup , , our beloved Country &amp; Fr...
# 30  Law in Philippines is for the poor helpless ci...
# 31  May nagawang mali man...Tama lang yon para sa ...
# 32         Where Is ICC during Palistine Genocide????
# 33  Akala ko ba sisipain mo ang ICC Digz bakit par...
# 34  HOY  de gong gong NAKAKAHIYA  KA KALA NG  MGA ...
# 35  Sana maging presidente ulit mnga Duterte para ...
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# 5                          NaN
# 6                          NaN
# 7                          NaN
# 8                          NaN
# 9                          NaN
# 10                         NaN
# 11                         NaN
# 12                         NaN
# 13                         NaN
# 14                         NaN
# 15                         NaN
# 16                         NaN
# 17                         NaN
# 18                         NaN
# 19                         NaN
# 20                         NaN
# 21                         NaN
# 22                         NaN
# 23                         NaN
# 24                         NaN
# 25                         NaN
# 26                         NaN
# 27                         NaN
# 28                         NaN
# 29                         NaN
# 30                         NaN
# 31                         NaN
# 32                         NaN
# 33                         NaN
# 34                         NaN
# 35                         NaN
# 36                         NaN
# 37                         NaN
# 38                         NaN
# 39                         NaN
# 40                         NaN
# 41  UgyGTcSyt76I3g0gPix4AaABAg
# 42                         NaN
# 43                         NaN
# 44                         NaN
# 45                         NaN
# 46                         NaN
# 47                         NaN
# 48                         NaN
# 49                         NaN
# 50                         NaN
# 51  UgzEdtXG7-BheRo3KZt4AaABAg
# 52  UgzEdtXG7-BheRo3KZt4AaABAg

# %% [markdown]
# ## Handling next page with page tokens

# %% [markdown]
# Let's take another example with more comments.
#
# We'll have a list of 50 or so comments from the video.
#
# However, if we check the video's comments section, we'll see that there are 128 comments in the video.
#
# So how can we extract more comments? That's where `pageToken` comes in.

# %%
video_id = 'xPb4FMfGbos'
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time'
).execute()

# iterate through items
for item in video_response['items']:

  # extract comment from each item
  comment = item['snippet']['topLevelComment']['snippet']

  # append comment to list of comments
  comments.append([
    comment['textDisplay'],
    f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
    comment['publishedAt'],
    comment['textOriginal'],
    comment['likeCount'],
    np.nan
  ])

  # count number of replies
  total_reply_count = item['snippet']['totalReplyCount']

  # if there is at least one reply
  if total_reply_count > 0:
    parent_id = item["snippet"]["topLevelComment"]["id"]

    replies = youtube.comments().list(
      part='snippet', parentId=parent_id, maxResults=50
    ).execute()

    # iterate through the replies
    for reply in replies['items']:
      # extract text from each reply
      # append reply to list of comments
      replyBody = reply['snippet']
      comments.append([
        replyBody['textDisplay'],
        f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
        replyBody['publishedAt'],
        replyBody['textOriginal'],
        replyBody['likeCount'],
        replyBody['parentId']
      ])

youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                  title  \
# 0                                        Sept 23, 2026
# 1    When Digong said to the Police who carried his...
# 2    ang tapang nuong hindi pa naaresto..dalian daw...
# 3    Life in prison please. <a href="UCkszU2WH9gy1m...
# 4                           Galing mag drama ni digong
# ..                                                 ...
# 101      Sa airplain palang me medical asssis na po ah
# 102  The Philippines is ridiculous. To voluntarily ...
# 103  Klasing imternational atty. yan di marunong ma...
# 104  kaya nga international Court. hindi ito americ...
# 105  hindi sinasamba ng ibang european contry ang e...
#
#                                                   link        date_published  \
# 0    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-07T14:01:01Z
# 1    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-03T20:45:50Z
# 2    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-01T07:29:49Z
# 3    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-25T22:06:40Z
# 4    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-10T14:28:05Z
# ..                                                 ...                   ...
# 101  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-21T13:18:13Z
# 102  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-21T11:11:32Z
# 103  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-21T10:07:04Z
# 104  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-21T10:45:08Z
# 105  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-21T10:46:09Z
#
#                                                   text  like_count  \
# 0                                        Sept 23, 2026           0
# 1    When Digong said to the Police who carried his...           0
# 2    ang tapang nuong hindi pa naaresto..dalian daw...           0
# 3                              Life in prison please.            0
# 4                           Galing mag drama ni digong           0
# ..                                                 ...         ...
# 101      Sa airplain palang me medical asssis na po ah           0
# 102  The Philippines is ridiculous. To voluntarily ...           0
# 103  Klasing imternational atty. yan di marunong ma...           0
# 104  kaya nga international Court. hindi ito americ...           1
# 105  hindi sinasamba ng ibang european contry ang e...           0
#
#                 reply_parent_id
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4                           NaN
# ..                          ...
# 101                         NaN
# 102                         NaN
# 103                         NaN
# 104  UgzEdtXG7-BheRo3KZt4AaABAg
# 105  UgzEdtXG7-BheRo3KZt4AaABAg
#
# [106 rows x 6 columns]

# %% [markdown]
# If we return to the contents of `video_response`, we'll see that one of its keys is the `nextPageToken` key. This key is like an ID that distinguishes the pages within a set of search results--in this case, the comments section of the video.
#
# If we add a `pageToken` argument to our `youtube.commentThreads().list()` method, you'll see that we will get different results from the previous one.

# %%
# Check whether video_response has `nextPageToken`
video_response['nextPageToken']
# Out:
# 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSUlCZ0FFZ1VJcUNBWUFCSUZDSWNnR0FBU0JRaWRJQmdCSWc0S0RBakg5UFMtQmhDUXd1VFVBdw=='

# %%
# Make the same request but with the `nextPageToken`
video_response_2 = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time',
  pageToken=video_response['nextPageToken']
).execute()

# %%
video_response_2['items'][0]['snippet']['topLevelComment']['snippet']['textDisplay']
# Out:
# 'Bat Si Putin at yung presedente ng israel  hindi inimbistigahan ng ICC na dami rin napatay na inosente sa pagkakaroon ng digmaan, unfair ICC'

# %% [markdown]
# Let's now incorporate `pageToken` into our loop.

# %%
# how many comments do we want
no_comments = 500

# re-initialize list of YouTube comments
comments = []
youtube_corpus = None

video_id = 'xPb4FMfGbos'  # more comments
# video_id = 'yfoq-0gGTLM' # fewer comments

# get first page of the comments
video_response = youtube.commentThreads().list(
  videoId=video_id, part='snippet,replies', maxResults=50,
  order='time', moderationStatus='published'
).execute()

while len(comments) < no_comments:
  # iterate through items
  for item in video_response['items']:
    ##### Parent Comments #####
    # extract comment from each item
    comment = item['snippet']['topLevelComment']['snippet']

    # append comment to list of comments
    comments.append([
      comment['textDisplay'],
      f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
      comment['publishedAt'],
      comment['textOriginal'],
      comment['likeCount'],
      np.nan
    ])

    ##### Reply Comments #####
    # count number of replies
    total_reply_count = item['snippet']['totalReplyCount']

    # if there is at least one reply
    if total_reply_count > 0:
      parent_id = item["snippet"]["topLevelComment"]["id"]

      replies = youtube.comments().list(
        part='snippet',
        parentId=parent_id
      ).execute()

      # iterate through the replies
      for reply in replies['items']:
        # extract text from each reply
        # append reply to list of comments
        replyBody = reply['snippet']
        comments.append([
          replyBody['textDisplay'],
          f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
          replyBody['publishedAt'],
          replyBody['textOriginal'],
          replyBody['likeCount'],
          replyBody['parentId']
        ])

  ##### Next Page #####
  # print number of comments
  print(str(len(comments)) + ' comments in list')

  # if there is a next page to the comment result
  if 'nextPageToken' in video_response:
    # notify that next page has been found
    print('Next comment page found. Now extracting data. \n')

    # get the next page
    video_response = youtube.commentThreads().list(
      videoId=video_id, part='snippet,replies', maxResults=50,
      order='time', pageToken=video_response['nextPageToken'],
      moderationStatus='published'
    ).execute()
  else:
    # notify that no more pages are left
    print('No more comment pages left.')
    break
# Out:
# 53 comments in list
# Next comment page found. Now extracting data.
#
# 110 comments in list
# Next comment page found. Now extracting data.
#
# 163 comments in list
# Next comment page found. Now extracting data.
#
# 217 comments in list
# Next comment page found. Now extracting data.
#
# 270 comments in list
# Next comment page found. Now extracting data.
#
# 322 comments in list
# Next comment page found. Now extracting data.
#
# 378 comments in list
# Next comment page found. Now extracting data.
#
# 431 comments in list
# Next comment page found. Now extracting data.
#
# 495 comments in list
# Next comment page found. Now extracting data.
#
# 550 comments in list
# Next comment page found. Now extracting data.

# %%
youtube_corpus = pd.DataFrame(
  comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id'])
youtube_corpus
# Out:
#                                                  title  \
# 0                                        Sept 23, 2026
# 1    When Digong said to the Police who carried his...
# 2    ang tapang nuong hindi pa naaresto..dalian daw...
# 3    Life in prison please. <a href="UCkszU2WH9gy1m...
# 4                           Galing mag drama ni digong
# ..                                                 ...
# 545                                  Bbm amd dds sucks
# 546                                                ❤❤❤
# 547  Diba sana si late Senator Miriam Santiago-Defe...
# 548                          Asan na yong sipa niya😂😂😂
# 549  This is a great mistake in prosecuting drug en...
#
#                                                   link        date_published  \
# 0    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-07T14:01:01Z
# 1    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-03T20:45:50Z
# 2    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-01T07:29:49Z
# 3    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-25T22:06:40Z
# 4    https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-10T14:28:05Z
# ..                                                 ...                   ...
# 545  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-16T07:32:44Z
# 546  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-16T07:30:44Z
# 547  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-16T07:30:26Z
# 548  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-16T07:29:31Z
# 549  https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-03-16T07:17:51Z
#
#                                                   text  like_count  \
# 0                                        Sept 23, 2026           0
# 1    When Digong said to the Police who carried his...           0
# 2    ang tapang nuong hindi pa naaresto..dalian daw...           0
# 3                              Life in prison please.            0
# 4                           Galing mag drama ni digong           0
# ..                                                 ...         ...
# 545                                  Bbm amd dds sucks           1
# 546                                                ❤❤❤           0
# 547  Diba sana si late Senator Miriam Santiago-Defe...           0
# 548                          Asan na yong sipa niya😂😂😂           0
# 549  This is a great mistake in prosecuting drug en...           0
#
#     reply_parent_id
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 545             NaN
# 546             NaN
# 547             NaN
# 548             NaN
# 549             NaN
#
# [550 rows x 6 columns]

# %% [markdown]
# ## Function `extract_youtube_comments`

# %% [markdown]
# Now, we can define a function that extracts a certain number of comments for a particular video and returns a list of these comments.

# %%
def extract_youtube_comments(video_id, no_comments):
  """
  Extracts comments from a YouTube video.

  Args:
    video_id (str): The ID of the YouTube video.
    no_comments (int): The number of comments to extract.

  Returns:
    pandas.DataFrame: A DataFrame containing the extracted comments with the following columns:
      - title (str): The display text of the comment.
      - link (str): The URL of the comment.
      - date_published (str): The date and time when the comment was published.
      - text (str): The original text of the comment.
      - like_count (int): The number of likes the comment has received.
      - reply_parent_id (float): The ID of the parent comment if the comment is a reply, otherwise NaN.
  """
  # re-initialize list of YouTube comments
  comments = []

  # get first page of the comments
  video_response = youtube.commentThreads().list(
    videoId=video_id, part='snippet,replies', maxResults=50,
    order='time', moderationStatus='published'
  ).execute()

  while len(comments) < no_comments:
    # iterate through items
    for item in video_response['items']:
      ##### Parent Comments #####
      # extract comment from each item
      comment = item['snippet']['topLevelComment']['snippet']

      # append comment to list of comments
      comments.append([
        comment['textDisplay'],
        f'https://www.youtube.com/watch?v={video_id}&lc={item["snippet"]["topLevelComment"]["id"]}',
        comment['publishedAt'],
        comment['textOriginal'],
        comment['likeCount'],
        np.nan
      ])

      ##### Reply Comments #####
      # count number of replies
      total_reply_count = item['snippet']['totalReplyCount']

      # if there is at least one reply
      if total_reply_count > 0:
        parent_id = item["snippet"]["topLevelComment"]["id"]

        replies = youtube.comments().list(
          part='snippet',
          parentId=parent_id
        ).execute()

        # iterate through the replies
        for reply in replies['items']:
          # extract text from each reply
          # append reply to list of comments
          replyBody = reply['snippet']
          comments.append([
            replyBody['textDisplay'],
            f"https://www.youtube.com/watch?v={video_id}&lc={reply['id']}",
            replyBody['publishedAt'],
            replyBody['textOriginal'],
            replyBody['likeCount'],
            replyBody['parentId']
          ])

    ##### Next Page #####
    # print number of comments
    print(str(len(comments)) + ' comments in list')

    # if there is a next page to the comment result
    if 'nextPageToken' in video_response:
      # notify that next page has been found
      print('Next comment page found. Now extracting data. \n')

      # get the next page
      video_response = youtube.commentThreads().list(
        videoId=video_id, part='snippet,replies', maxResults=50,
        order='time', pageToken=video_response['nextPageToken'],
        moderationStatus='published'
      ).execute()
    else:
      # notify that no more pages are left
      print('No more comment pages left.\n')
      break

  return pd.DataFrame(
    comments, columns=['title', 'link', 'date_published', 'text', 'like_count', 'reply_parent_id']
  )

# %%
video_links = [
  'xPb4FMfGbos',  # more comments
  'yfoq-0gGTLM'  # fewer comments
]

youtube_corpus = None

for video_link in video_links:
  print(f'Extracting comments from video: {video_link}')
  if youtube_corpus is None:
    youtube_corpus = extract_youtube_comments(video_link, 750)
  else:
    youtube_corpus = pd.concat([
      youtube_corpus, extract_youtube_comments(video_link, 750)
    ])

youtube_corpus
# Out:
# Extracting comments from video: xPb4FMfGbos
# 53 comments in list
# Next comment page found. Now extracting data.
#
# 110 comments in list
# Next comment page found. Now extracting data.
#
# 163 comments in list
# Next comment page found. Now extracting data.
#
# 217 comments in list
# Next comment page found. Now extracting data.
#
# 270 comments in list
# Next comment page found. Now extracting data.
#
# 322 comments in list
# Next comment page found. Now extracting data.
#
# 378 comments in list
# Next comment page found. Now extracting data.
#
# 431 comments in list
# Next comment page found. Now extracting data.
#
# 495 comments in list
# Next comment page found. Now extracting data.
#
# 550 comments in list
# Next comment page found. Now extracting data.
#
# 619 comments in list
# Next comment page found. Now extracting data.
#
# 675 comments in list
# Next comment page found. Now extracting data.
#
# 731 comments in list
# Next comment page found. Now extracting data.
#
# 789 comments in list
# Next comment page found. Now extracting data.
#
# Extracting comments from video: yfoq-0gGTLM
# 37 comments in list
# No more comment pages left.
#                                                 title  \
# 0                                       Sept 23, 2026
# 1   When Digong said to the Police who carried his...
# 2   ang tapang nuong hindi pa naaresto..dalian daw...
# 3   Life in prison please. <a href="UCkszU2WH9gy1m...
# 4                          Galing mag drama ni digong
# ..                                                ...
# 32  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...
# 33  That vp is rude, entitled and arrogant like he...
# 34            What country is this? Very interesting.
# 35                          @@cvoutdoors9859palamunin
# 36                                        That’s true
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-07T14:01:01Z
# 1   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-03T20:45:50Z
# 2   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-01T07:29:49Z
# 3   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-25T22:06:40Z
# 4   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-10T14:28:05Z
# ..                                                ...                   ...
# 32  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:24:46Z
# 33  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:13:32Z
# 34  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:16:52Z
# 35  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:14:26Z
# 36  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T18:00:32Z
#
#                                                  text  like_count  \
# 0                                       Sept 23, 2026           0
# 1   When Digong said to the Police who carried his...           0
# 2   ang tapang nuong hindi pa naaresto..dalian daw...           0
# 3                             Life in prison please.            0
# 4                          Galing mag drama ni digong           0
# ..                                                ...         ...
# 32  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...           0
# 33  That vp is rude, entitled and arrogant like he...           3
# 34            What country is this? Very interesting.           0
# 35                          @@cvoutdoors9859palamunin           0
# 36                                        That’s true           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 32  UgwBBzeGtqWna6y4KUJ4AaABAg
# 33  UgwBBzeGtqWna6y4KUJ4AaABAg
# 34  UgwBBzeGtqWna6y4KUJ4AaABAg
# 35  UgwBBzeGtqWna6y4KUJ4AaABAg
# 36  UgwBBzeGtqWna6y4KUJ4AaABAg
#
# [826 rows x 6 columns]

# %%
youtube_corpus
# Out:
#                                                 title  \
# 0                                       Sept 23, 2026
# 1   When Digong said to the Police who carried his...
# 2   ang tapang nuong hindi pa naaresto..dalian daw...
# 3   Life in prison please. <a href="UCkszU2WH9gy1m...
# 4                          Galing mag drama ni digong
# ..                                                ...
# 32  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...
# 33  That vp is rude, entitled and arrogant like he...
# 34            What country is this? Very interesting.
# 35                          @@cvoutdoors9859palamunin
# 36                                        That’s true
#
#                                                  link        date_published  \
# 0   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-07T14:01:01Z
# 1   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-03T20:45:50Z
# 2   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-08-01T07:29:49Z
# 3   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-25T22:06:40Z
# 4   https://www.youtube.com/watch?v=xPb4FMfGbos&lc...  2025-07-10T14:28:05Z
# ..                                                ...                   ...
# 32  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T11:24:46Z
# 33  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T13:13:32Z
# 34  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T14:16:52Z
# 35  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T15:14:26Z
# 36  https://www.youtube.com/watch?v=yfoq-0gGTLM&lc...  2024-08-27T18:00:32Z
#
#                                                  text  like_count  \
# 0                                       Sept 23, 2026           0
# 1   When Digong said to the Police who carried his...           0
# 2   ang tapang nuong hindi pa naaresto..dalian daw...           0
# 3                             Life in prison please.            0
# 4                          Galing mag drama ni digong           0
# ..                                                ...         ...
# 32  Ul*l dignified. Pinapakyuhan nga si Bong Daza ...           0
# 33  That vp is rude, entitled and arrogant like he...           3
# 34            What country is this? Very interesting.           0
# 35                          @@cvoutdoors9859palamunin           0
# 36                                        That’s true           0
#
#                reply_parent_id
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
# ..                         ...
# 32  UgwBBzeGtqWna6y4KUJ4AaABAg
# 33  UgwBBzeGtqWna6y4KUJ4AaABAg
# 34  UgwBBzeGtqWna6y4KUJ4AaABAg
# 35  UgwBBzeGtqWna6y4KUJ4AaABAg
# 36  UgwBBzeGtqWna6y4KUJ4AaABAg
#
# [826 rows x 6 columns]

# %% [markdown]
# We can now save these comments to a dataframe and Excel file.

# %%
try:
  # Google Colab
  from google.colab import drive  # type: ignore
  drive.mount('/content/drive')

  file_name = '/content/drive/MyDrive/youtube_corpus.xlsx'
except:
  # VS Code / Local machine
  file_name = 'youtube_corpus.xlsx'

youtube_corpus.to_excel(file_name)
print(f'File saved to {file_name}')
# Out:
# File saved to youtube_corpus.xlsx

# %% [markdown]
# What we've done so far is extract comments for **one** video. If you want to extract comments for multiple videos, you'll have to use the `channel`, `search`, or `playlist` resource objects of the YouTube API. You can study these more through the documentation.
#
# However, note that each account has an allocation of 10,000 units per day. Each call that uses the API costs a certain number of units, and if you reach 10,000, you won't be able to properly use the API (and possibly YouTube) until the next day.

# %% [markdown]
# Other APIs you might be interested in exploring:
# *   Genius API for extracting song lyrics (https://docs.genius.com/)
# *   Python Reddit API Wrapper (PRAW) for extracting Reddit posts (https://praw.readthedocs.io/en/stable/)
# *   Tweepy for extracting tweets (but Elon kinda ruined it now) (https://www.tweepy.org/)

# %% [markdown]
# # Method 3: Facepager

# %% [markdown]
# Facepager is an application made for automating data extraction (esp. for Facebook). Follow the installation instructions in this page: https://github.com/strohne/Facepager

# %% [markdown]
# To learn more about how to use Facepager, navigate through its wiki page: https://github.com/strohne/Facepager/wiki/Getting-Started
